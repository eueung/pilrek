# %% [markdown]
# # UTS ET3107 Pemrograman Lanjut/Advanced Programming

# %% [markdown]
# ## Data diambil dari github.com/eueung/pilrek (update 08/10/2019)

# %% [markdown]
# Update
# (dilansir dari https://bandung.kompas.com/read/2019/10/11/09041361/10-bakal-calon-rektor-itb-ditetapkan-ini-nama-namanya?page=all)
# > Majelis Wali Amanat (MWA) ITB telah menentukan 10 bakal calon rektor yang lolos ke tahap selanjutnya, yaitu
# 1. Benyamin Sapiie
# 2. Bramantyo Djohanputro
# 3. Dwi Larso
# 4. Edy Tri Baskoro
# 5. Gusti Ayu Putri Saptawati
# 6. Jaka Sembiring
# 7. Kadarsyah Suryadi
# 8. Reini D Wirahadikusumah
# 9. Togar Mangihut Simatupang
# 10. Widjaja Martokusumo

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# mengunduh data terbaru dari github Pak Eueung
df1 = pd.read_csv('https://github.com/eueung/pilrek/raw/master/pilrek.csv')
df2 = pd.read_csv('https://github.com/eueung/pilrek/raw/master/pilrek-anon.csv')
df  = pd.concat([df1, df2])

# %%
df.tail()
# Out:
#                Timestamp     Kategori Anda Kategori Umur Anda  \
# 2024   9/25/2019 8:54:33              Umum         25 - 40 th
# 2025  9/26/2019 13:30:25  Pegawai / Tendik         25 - 40 th
# 2026  10/8/2019 14:28:00            Alumni         25 - 40 th
# 2027  10/8/2019 14:59:53            Alumni            > 40 th
# 2028  10/8/2019 15:10:17            Alumni            > 40 th
#
#                   CaRek Pilihan                          Alasan Memilih CaRek  \
# 2024  Dicky Rezady Munaf (FSRD)                     Keberhasilan dan prestasi
# 2025  Kadarsah Suryadi (FTI-TI)    Kecerdasan dan keberanian utk kemajuan ITB
# 2026      Dewi Larasati (SAPPK)        Emansipasi, kesetaraan dan kebhinekaan
# 2027      Dewi Larasati (SAPPK)                       Akhlak dan budi pekerti
# 2028      Dewi Larasati (SAPPK)  Sesuai dengan kriteria kekinian (Rektor 4.0)
#
#                                            Harapan Anda
# 2024  Yang bersangkutan telah berhasil dalam mengemb...
# 2025                                                NaN
# 2026                                                NaN
# 2027  ITB jadi universitas yang melahirkan tokoh2 du...
# 2028                         Semoga terpilih dan sukses

# %% [markdown]
# ### Menyaring data supaya data bacarek yang digunakan untuk pengolahan data hanya bacarek yang lolos ke tahap selanjutnya

# %%
df_lolos = df[df['CaRek Pilihan'].str.contains('Benyamin|'
                                              'Bramantyo|'
                                             'Dwi|'
                                             'Edy|'
                                             'Gusti Ayu|'
                                             'Jaka|'
                                             'Kadarsah|'
                                             'Reini|'
                                             'Simatupang|'
                                             'Martokusumo')]

# %%
df_lolos
# Out:
#                Timestamp     Kategori Anda Kategori Umur Anda  \
# 0       9/1/2019 7:47:18            Alumni         25 - 40 th
# 4      9/1/2019 12:25:40             Dosen         25 - 40 th
# 9      9/1/2019 13:58:03              Umum            > 40 th
# 10     9/1/2019 14:00:04             Dosen            > 40 th
# 12     9/1/2019 14:01:25              Umum         25 - 40 th
# 16     9/1/2019 14:03:29             Dosen            > 40 th
# 26     9/1/2019 14:28:52            Alumni            > 40 th
# 29     9/1/2019 14:34:43         Mahasiswa            < 25 th
# 66     9/1/2019 15:38:18         Mahasiswa            < 25 th
# 70     9/1/2019 15:44:38            Alumni            > 40 th
# 77     9/1/2019 16:05:55            Alumni            > 40 th
# 100    9/1/2019 17:01:03            Alumni         25 - 40 th
# 106    9/1/2019 17:23:35              Umum            > 40 th
# 108    9/1/2019 17:28:31             Dosen            > 40 th
# 109    9/1/2019 17:29:24         Mahasiswa            < 25 th
# 116    9/1/2019 17:55:17             Dosen            > 40 th
# 117    9/1/2019 17:55:48            Alumni            > 40 th
# 118    9/1/2019 17:56:00             Dosen            > 40 th
# 119    9/1/2019 17:57:01             Dosen            > 40 th
# 130    9/1/2019 18:42:19            Alumni            > 40 th
# 132    9/1/2019 18:45:52            Alumni            > 40 th
# 151    9/1/2019 19:44:13             Dosen            > 40 th
# 156    9/1/2019 20:06:31            Alumni            > 40 th
# 160    9/1/2019 20:21:34            Alumni            > 40 th
# 162    9/1/2019 20:25:25            Alumni            > 40 th
# 163    9/1/2019 20:28:15         Mahasiswa            < 25 th
# 164    9/1/2019 20:32:44            Alumni            > 40 th
# 165    9/1/2019 20:37:47            Alumni            > 40 th
# 166    9/1/2019 20:46:39            Alumni            > 40 th
# 167    9/1/2019 20:47:29            Alumni            > 40 th
# ...                  ...               ...                ...
# 1846  9/10/2019 11:33:20            Alumni         25 - 40 th
# 1847  9/10/2019 12:14:47            Alumni            > 40 th
# 1850  9/10/2019 21:41:40            Alumni            > 40 th
# 1852   9/11/2019 8:51:05             Dosen            > 40 th
# 1854  9/11/2019 10:32:28             Dosen         25 - 40 th
# 1883  9/14/2019 14:43:16              Umum            > 40 th
# 1884  9/14/2019 14:43:19              Umum         25 - 40 th
# 1892  9/14/2019 14:56:54             Dosen         25 - 40 th
# 1901  9/14/2019 15:31:36              Umum         25 - 40 th
# 1910  9/14/2019 15:47:05             Dosen            > 40 th
# 1911  9/14/2019 15:48:26              Umum            > 40 th
# 1923  9/14/2019 16:21:57             Dosen         25 - 40 th
# 1935  9/14/2019 17:27:30            Alumni            > 40 th
# 1947  9/14/2019 18:35:25              Umum         25 - 40 th
# 1948  9/14/2019 18:36:50              Umum         25 - 40 th
# 1949  9/14/2019 18:56:28              Umum            > 40 th
# 1954  9/14/2019 19:57:22            Alumni            > 40 th
# 1955  9/14/2019 20:00:03         Mahasiswa            < 25 th
# 1958  9/14/2019 20:08:39              Umum            > 40 th
# 1960  9/14/2019 20:53:54              Umum            > 40 th
# 1965  9/14/2019 21:27:31  Pegawai / Tendik            > 40 th
# 1966  9/14/2019 22:18:23              Umum            < 25 th
# 1967  9/14/2019 22:21:05              Umum            < 25 th
# 1974   9/15/2019 6:37:46             Dosen         25 - 40 th
# 1976   9/15/2019 7:56:37              Umum            < 25 th
# 1984   9/15/2019 9:01:53              Umum            > 40 th
# 2008  9/16/2019 10:45:44              Umum         25 - 40 th
# 2012  9/16/2019 17:14:53              Umum            < 25 th
# 2015  9/17/2019 22:27:18         Mahasiswa            < 25 th
# 2025  9/26/2019 13:30:25  Pegawai / Tendik         25 - 40 th
#
#                            CaRek Pilihan  \
# 0                  Jaka Sembiring (STEI)
# 4              Kadarsah Suryadi (FTI-TI)
# 9               Togar M Simatupang (SBM)
# 10                 Jaka Sembiring (STEI)
# 12              Togar M Simatupang (SBM)
# 16             Kadarsah Suryadi (FTI-TI)
# 26      Dwi Larso (SBM / President Univ)
# 29            Edy Tri Baskoro (FMIPA-MA)
# 66            Edy Tri Baskoro (FMIPA-MA)
# 70                Benyamin Sapiie (FITB)
# 77                Benyamin Sapiie (FITB)
# 100               Benyamin Sapiie (FITB)
# 106            Kadarsah Suryadi (FTI-TI)
# 108             Togar M Simatupang (SBM)
# 109            Kadarsah Suryadi (FTI-TI)
# 116             Togar M Simatupang (SBM)
# 117             Togar M Simatupang (SBM)
# 118             Togar M Simatupang (SBM)
# 119             Togar M Simatupang (SBM)
# 130       Reini D Wirahadikusumah (FTSL)
# 132               Benyamin Sapiie (FITB)
# 151     Dwi Larso (SBM / President Univ)
# 156     Dwi Larso (SBM / President Univ)
# 160               Benyamin Sapiie (FITB)
# 162     Dwi Larso (SBM / President Univ)
# 163             Togar M Simatupang (SBM)
# 164     Dwi Larso (SBM / President Univ)
# 165     Dwi Larso (SBM / President Univ)
# 166     Dwi Larso (SBM / President Univ)
# 167     Dwi Larso (SBM / President Univ)
# ...                                  ...
# 1846              Benyamin Sapiie (FITB)
# 1847               Jaka Sembiring (STEI)
# 1850          Edy Tri Baskoro (FMIPA-MA)
# 1852           Kadarsah Suryadi (FTI-TI)
# 1854          Edy Tri Baskoro (FMIPA-MA)
# 1883          Edy Tri Baskoro (FMIPA-MA)
# 1884          Edy Tri Baskoro (FMIPA-MA)
# 1892            Togar M Simatupang (SBM)
# 1901          Edy Tri Baskoro (FMIPA-MA)
# 1910          Edy Tri Baskoro (FMIPA-MA)
# 1911          Edy Tri Baskoro (FMIPA-MA)
# 1923          Edy Tri Baskoro (FMIPA-MA)
# 1935          Edy Tri Baskoro (FMIPA-MA)
# 1947          Edy Tri Baskoro (FMIPA-MA)
# 1948          Edy Tri Baskoro (FMIPA-MA)
# 1949          Edy Tri Baskoro (FMIPA-MA)
# 1954  Gusti Ayu Putri Saptawati S (STEI)
# 1955          Edy Tri Baskoro (FMIPA-MA)
# 1958          Edy Tri Baskoro (FMIPA-MA)
# 1960          Edy Tri Baskoro (FMIPA-MA)
# 1965          Edy Tri Baskoro (FMIPA-MA)
# 1966          Edy Tri Baskoro (FMIPA-MA)
# 1967          Edy Tri Baskoro (FMIPA-MA)
# 1974          Edy Tri Baskoro (FMIPA-MA)
# 1976          Edy Tri Baskoro (FMIPA-MA)
# 1984          Edy Tri Baskoro (FMIPA-MA)
# 2008          Edy Tri Baskoro (FMIPA-MA)
# 2012  Bramantyo (Direktur PPM Manajemen)
# 2015           Kadarsah Suryadi (FTI-TI)
# 2025           Kadarsah Suryadi (FTI-TI)
#
#                                    Alasan Memilih CaRek  \
# 0          Sesuai dengan kriteria kekinian (Rektor 4.0)
# 4                  Karakter kepemimpinan dan leadership
# 9                             Keberhasilan dan prestasi
# 10           Kecerdasan dan keberanian utk kemajuan ITB
# 12                            Keberhasilan dan prestasi
# 16                            Keberhasilan dan prestasi
# 26         Kapabilitas ybs utk meningkatkan ranking ITB
# 29                            Keberhasilan dan prestasi
# 66                            Keberhasilan dan prestasi
# 70                            Keberhasilan dan prestasi
# 77    Tipe yg futuristik dan outside-the-box yg bisa...
# 100                           Keberhasilan dan prestasi
# 106   Kapabilitas ybs utk memajukan riset dan indust...
# 108   Tipe yg futuristik dan outside-the-box yg bisa...
# 109                           Keberhasilan dan prestasi
# 116   Tipe yg futuristik dan outside-the-box yg bisa...
# 117   Kapabilitas ybs utk memajukan riset dan indust...
# 118   Tipe yg futuristik dan outside-the-box yg bisa...
# 119   Tipe yg futuristik dan outside-the-box yg bisa...
# 130   Kapabilitas ybs utk memajukan riset dan indust...
# 132   Kapabilitas ybs utk memajukan riset dan indust...
# 151            Kapabilitas dalam membangun enterpreneur
# 156        Sesuai dengan kriteria kekinian (Rektor 4.0)
# 160        Sesuai dengan kriteria kekinian (Rektor 4.0)
# 162          Kecerdasan dan keberanian utk kemajuan ITB
# 163                             Akhlak dan budi pekerti
# 164        Kapabilitas ybs utk meningkatkan ranking ITB
# 165        Kapabilitas ybs utk meningkatkan ranking ITB
# 166                Karakter kepemimpinan dan leadership
# 167        Sesuai dengan kriteria kekinian (Rektor 4.0)
# ...                                                 ...
# 1846                          Keberhasilan dan prestasi
# 1847  Tipe yg futuristik dan outside-the-box yg bisa...
# 1850       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 1852  Program ybs utk peningkatan income dan kesejah...
# 1854                            Akhlak dan budi pekerti
# 1883       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 1884               Karakter kepemimpinan dan leadership
# 1892       Kapabilitas ybs utk meningkatkan ranking ITB
# 1901                          Keberhasilan dan prestasi
# 1910                          Keberhasilan dan prestasi
# 1911               Karakter kepemimpinan dan leadership
# 1923       Kapabilitas ybs utk meningkatkan ranking ITB
# 1935               Karakter kepemimpinan dan leadership
# 1947         Kecerdasan dan keberanian utk kemajuan ITB
# 1948                            Akhlak dan budi pekerti
# 1949                          Keberhasilan dan prestasi
# 1954             Emansipasi, kesetaraan dan kebhinekaan
# 1955  Kapabilitas ybs utk memajukan riset dan indust...
# 1958                          Keberhasilan dan prestasi
# 1960               Karakter kepemimpinan dan leadership
# 1965       Kapabilitas ybs utk meningkatkan ranking ITB
# 1966       Kapabilitas ybs utk meningkatkan ranking ITB
# 1967                          Keberhasilan dan prestasi
# 1974                          Keberhasilan dan prestasi
# 1976               Karakter kepemimpinan dan leadership
# 1984                          Keberhasilan dan prestasi
# 2008       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 2012         Kecerdasan dan keberanian utk kemajuan ITB
# 2015       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 2025         Kecerdasan dan keberanian utk kemajuan ITB
#
#                                            Harapan Anda
# 0                                                   NaN
# 4                                                   NaN
# 9     Prof. Togar Simatupang, memiliki kapabilitas m...
# 10    Semoga Rektor yang terpiih mampu membawa perub...
# 12     Prof. Togar Simatupang semoga dapat memimpin ...
# 16    ITB dekat sama masyarakat , solusi bagi bangsa...
# 26                                                  NaN
# 29                        Semoga sukses ke depannya ITB
# 66               Semoga dapat menjadi ITB internasional
# 70              Prof Benyamin Safeii bisa memajukan ITB
# 77    ITB menjadi lembaga pendidikan Teknik yang mam...
# 100                                   Pendidikan gratis
# 106                       ranking dunia ITB makin bagus
# 108                         Bring ITB to the next level
# 109                                                 NaN
# 116   Bisa menjawab tantangan dunia pendidikan dua l...
# 117   Pilih rektor yg punya pengalaman di dunia pend...
# 118   Bisa menjawab tantangan dunia pendidikan dua l...
# 119   Fapan menjawan tantangan dunia pendidikan dia ...
# 130                                                 NaN
# 132   Semoga itb bs semakin maju terus menjadi the b...
# 151                                                 NaN
# 156                                                 NaN
# 160   Komunitas ITB bebas dari radikalisme dan ide k...
# 162   Agar pak Dwi Larso lbh bs lbh jauh lg memajuka...
# 163   Demo yang terpilih benar benar punya tujuan mu...
# 164   ITB bisa jd perguruan tinggi rujukan minimal d...
# 165                                        ITB mendunia
# 166   Mengembalikan marwah ITB sbg sll yang terbaik ...
# 167   inshaaa Alloh ITB semakin lebih baik dan barok...
# ...                                                 ...
# 1846                                                NaN
# 1847  ITB akan semakin maju dan masuk Top 100 di tar...
# 1850                            Itb semakin berprestasi
# 1852  Rektor ITB ke depan fapat menjadi good father ...
# 1854                                      Semoga amanah
# 1883                                   Itb tbh lbh jaya
# 1884                Semoga lebih baik dari sebelumnya\n
# 1892                                                NaN
# 1901  Semoga dipimpin bp Edy Baskoro tambh mantappp ...
# 1910  Semoga terpilih menjadi rektor ITB periode 202...
# 1911                                                NaN
# 1923                                                NaN
# 1935                                                NaN
# 1947                                                NaN
# 1948                                                NaN
# 1949                                   ITB semakin jaya
# 1954                         Itb world class university
# 1955                                                NaN
# 1958                                  Sukses n berhasil
# 1960                        Terpilih menjadi Rektor ITB
# 1965  moga dengan kepemimpinan beliau dpt mengantark...
# 1966                                                NaN
# 1967                                                NaN
# 1974                                                NaN
# 1976                                                NaN
# 1984             Membawa ITB lebih maju dan lebih baik
# 2008  Semoga Bapak Edy bisa membawa ITB menjadi lebi...
# 2012                                                NaN
# 2015                                                NaN
# 2025                                                NaN
#
# [1004 rows x 6 columns]

# %% [markdown]
# ### Menampilkan jumlah pilihan bacarek

# %%
df_lolos['CaRek Pilihan'].value_counts().plot.bar()
plt.title("Gambar 1: Grafik jumlah pilihan bacarek")
# Out:
# Text(0.5, 1.0, 'Gambar 1: Grafik jumlah pilihan bacarek')

# %% [markdown]
# ## 1. Klasifikasi data berdasarkan lembaga asal bacarek

# %% [markdown]
# Berdasarkan gambar 1, terdapat sembilan bacarek yang berasal dari kalangan civitas akademika ITB yaitu:
# 1. Edy Tri Baskoro (FMIPA-MA)
# 2. Kadarsah Suryadi (FTI-TI)
# 3. Benyamin Sapiie (FITB)
# 4. Dwi Larso (SBM/President Univ)
# 5. Jaka Sembiring (STEI)
# 6. Togar M Simatupang (SBM)
# 7. Gusti Ayu Putri Saptawati S (STEI)
# 8. Widjaja Martokusumo (SAPPK)
# 9. Reini D Wirahadikusumah (FTSL)
# dan terdapat satu bacarek yang berasal dari luar civitas akademika ITB yaitu Bramantyo (Direktur PPM Manajemen).
#
# Para bacarek yang berasal dari civitas akademika ITB berasal dari fakultas/sekolah FMIPA, FTI, FITB, SBM, STEI, SAPPK, dan FTSL.
#
# Selanjutnya melalui data yang tersedia ditinjau latar belakang asal pemilih yang memilih masing-masing kategori di atas. Terdapat dua kategori yaitu civitas akademika ITB (mahasiswa, dosen, dan pegawai tenaga kependidikan) dan luar ITB (alumni dan umum).

# %% [markdown]
# ### Persentase latar belakang pekerjaan pemilih bacarek yang berasal dari ITB

# %%
df_lolos_itb = df_lolos[df_lolos['CaRek Pilihan'].str.contains('FMIPA|'
                                                              'FTI|'
                                                              'FITB|'
                                                              'SBM|'
                                                              'STEI|'
                                                              'SAPPK|'
                                                              'FTSL')]
#df_lolos_itb

# %%
ax2 = df_lolos_itb['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax2.set_ylabel('')
plt.title("Gambar 2: Persentase latar belakang pekerjaan pemilih bacarek yang berasal dari ITB")
# Out:
# Text(0.5, 1.0, 'Gambar 2: Persentase latar belakang pekerjaan pemilih bacarek yang berasal dari ITB')

# %% [markdown]
# ### Persentase latar belakang pekerjaan pemilih bacarek yang berasal dari luar ITB

# %%
df_lolos_nonitb = df_lolos[df_lolos['CaRek Pilihan'].str.contains('PPM')]
#df_lolos_nonitb

# %%
ax3 = df_lolos_nonitb['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax3.set_ylabel('')
plt.title("Gambar 3: Persentase latar belakang pekerjaan pemilih bacarek yang berasal dari luar ITB")
# Out:
# Text(0.5, 1.0, 'Gambar 3: Persentase latar belakang pekerjaan pemilih bacarek yang berasal dari luar ITB')

# %% [markdown]
# ### Analisis
# Dari gambar 2 tampak bahwa **bacarek yang berasal dari ITB** mendapatkan cukup banyak dukungan dari **kalangan civitas akademika** (dosen, mahasiswa, dan pegawai tenaga kependidikan) dengan total persentase pemilih hingga 48.1%. Dukungan dari luar ITB (alumni dan umum) sedikit lebih banyak dengan total 51.8%, tetapi tidak cukup mendominasi.
#
# Dari gambar 3 tampak bahwa **bacarek yang berasal dari luar ITB** mendapatkan dukungan yang **didominasi oleh kalangan luar ITB** dengan total pemilih hingga 85.7%. Kalangan civitas akademika ITB yang memilih bacarek yang berasal dari luar ITB cukup sedikit, dengan total hanya 14.4%.

# %% [markdown]
# ## 2. Klasifikasi data berdasarkan latar belakang akademik bacarek

# %% [markdown]
# Berdasarkan gambar 1, latar belakang akademik bacarek dapat dikelompokkan sebagai berikut.
# 1. Sains dan teknologi
#     - Edy Tri Baskoro (FMIPA-MA)
#     - Kadarsah Suryadi (FTI-TI)
#     - Benyamin Sapiie (FITB)
#     - Jaka Sembiring (STEI)
#     - Gusti Ayu Putri Saptawati S (STEI)
#     - Widjaja Martokusumo (SAPPK)
#     - Reini D Wirahadikusumah (FTSL)
#
#
# 2. Bisnis dan manajemen
#     - Dwi Larso (SBM/President Univ)
#     - Togar M Simatupang (SBM)
#
# Selanjutnya ditinjau alasan memilih bacarek dari masing-masing kategori di atas.

# %% [markdown]
# ### Persentase alasan pemilih yang memilih bacarek dari rumpun saintek

# %%
df_saintek = df_lolos[df_lolos['CaRek Pilihan'].str.contains('FMIPA|'
                                                              'FTI|'
                                                              'FITB|'
                                                              'STEI|'
                                                              'SAPPK|'
                                                              'FTSL')]
#df_saintek

# %%
ax4 = df_saintek['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax4.set_ylabel('')
plt.title("Gambar 4: Persentase alasan pemilih yang memilih bacarek dari rumpun saintek")
# Out:
# Text(0.5, 1.0, 'Gambar 4: Persentase alasan pemilih yang memilih bacarek dari rumpun saintek')

# %% [markdown]
# ### Persentase alasan pemilih yang memilih bacarek dari rumpun bisnis-manajemen

# %%
df_bisman = df_lolos[df_lolos['CaRek Pilihan'].str.contains('SBM')]
#df_bisman

# %%
ax5 = df_bisman['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax5.set_ylabel('')
plt.title("Gambar 5: Persentase alasan pemilih yang memilih bacarek dari rumpun bisnis-manajemen")
# Out:
# Text(0.5, 1.0, 'Gambar 5: Persentase alasan pemilih yang memilih bacarek dari rumpun bisnis-manajemen')

# %% [markdown]
# ### Analisis

# %% [markdown]
# Berdasarkan gambar 4, pemilih yang memilih bacarek dari rumpun saintek memiliki lima alasan terbanyak sebagai berikut:
# 1. Keberhasilan dan prestasi (24.9%)
# 2. Rektor 4.0 (11.8%)
# 3. Karakter kepemimpinan dan leadership (11.3%)
# 4. Kecerdasan dan keberanian utk kemajuan ITB (10.7%)
# 5. Kapabilitas utk meningkatkan ranking ITB (7.7%)
#
# Berdasarkan gambar 5, pemilih yang memilih bacarek dari rumpun bisnis-manajemen memiliki lima alasan terbanyak sebagai berikut:
# 1. Kecerdasan dan keberanian utk kemajuan ITB (25.0%)
# 2. Rektor 4.0 (13.8%)
# 3. Kapabilitas utk meningkatkan ranking ITB (13.8%)
# 4. Futuristik dan outside-the-box (12.5%)
# 5. Keberhasilan dan prestasi (7.5%)
#
# Dari deskripsi di atas dapat dibandingkan perbedaan sifat-sifat yang dimiliki oleh bacarek dari rumpun saintek dan bisnis-manajemen:
# - Bacarek dari kedua rumpun tersebut sama-sama dianggap **kekinian (Rektor 4.0)**, **cukup cerdas dan berani untuk memajukan ITB**, dan dianggap **mampu meningkatkan ranking ITB**.
# - Pemilih yang memilih bacarek dari rumpun **saintek** paling banyak memilih berdasarkan **pencapaian/prestasi pribadi** bacarek (keberhasilan dan prestasi) dengan persentase mencapai 24.9%.
# - Pemilih yang memilih bacarek dari rumpun **bisnis-manajemen** paling banyak memilih berdasarkan **kepribadian** bacarek (kecerdasan dan keberanian) dengan persentase mencapai 25.0%.
# - Terdapat alasan yang hanya terdapat pada bacarek yang berasal dari **saintek**, yaitu **karakter kepemimpinan dan leadership** (11.3%).
# - Terdapat alasan yang hanya terdapat pada bacarek yang berasal dari **bisnis-manajemen**, yaitu **futuristik dan outside-the-box** (12.5%)

# %%
timestamp = df_lolos['Timestamp'].str.split(expand=True)
tanggal = timestamp[0].str.split('/',expand=True)
waktu = timestamp[1].str.split(':',expand=True)
print('sample tanggal\n', tanggal.sample(),'\n')
print('sample waktu\n', waktu.sample())
# Out:
# sample tanggal
#       0  1     2
# 388  9  2  2019
#
# sample waktu
#        0   1   2
# 1744  5  55  52

# %%
jam = waktu[0].astype(int).value_counts().sort_index()
jam = jam.reindex(np.arange(jam.index[0],jam.index[-1]+1),fill_value=0)
am = jam[:12]
pm = jam[12:]
print(am,'\n',pm)
# Out:
# 0      9
# 1      4
# 2      1
# 3      0
# 4     17
# 5     24
# 6     31
# 7     46
# 8     38
# 9     30
# 10    25
# 11    55
# Name: 0, dtype: int64
#  12     20
# 13    113
# 14     91
# 15     65
# 16     38
# 17     77
# 18    100
# 19     32
# 20     59
# 21     70
# 22     55
# 23      4
# Name: 0, dtype: int64

# %%
N = 12
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
width = np.pi / 6
radii = am

ax = plt.subplot(121,projection='polar')
bars = ax.bar(theta, radii, width=width, bottom=0.0, edgecolor='black')

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.viridis(r / radii.max()))
    bar.set_alpha(0.8)
    
ax.set_theta_zero_location("N")
ax.set_theta_direction(-1)
ax.set_xticks(theta)
ax.set_xticklabels(np.append(12,np.arange(1,N)).flatten())
ax.set_title('am', y =1)

radii = pm
with plt.style.context('dark_background'):
    ax = plt.subplot(122,projection='polar')
    bars = ax.bar(theta, radii, width=width, bottom=0.0, edgecolor='white')

    # Use custom colors and opacity
    for r, bar in zip(radii, bars):
        bar.set_facecolor(plt.cm.twilight(r / radii.max()))
        bar.set_alpha(0.9)

    ax.set_theta_zero_location("N")
    ax.set_theta_direction(-1)
    ax.set_rlabel_position(-30)
    ax.set_xticks(theta)
    ax.set_xticklabels(np.append(12,np.arange(1,N)).flatten(),c='black')
    ax.set_title('pm',y = 1,c='black')

plt.suptitle('Jumlah Entri Kuisioner carek lolos Berdasarkan Waktu')
plt.tight_layout()
