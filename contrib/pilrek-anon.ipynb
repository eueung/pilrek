# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
df  = pd.read_csv('pilrek-anon.csv')
df.columns = ['Timestamp', 'Kategori', 'Umur', 'Carek', 'Alasan', 'Harapan']

# %%
count_df = df['Carek'].value_counts()
new_df = df[df['Carek'].isin(count_df[count_df > count_df.mean()].index)]
new_df
# Out:
#                Timestamp          Kategori        Umur  \
# 14     9/1/2019 12:26:02             Dosen     > 40 th
# 16     9/1/2019 12:41:27             Dosen     > 40 th
# 18     9/1/2019 13:11:56             Dosen  25 - 40 th
# 19     9/1/2019 13:36:50  Pegawai / Tendik  25 - 40 th
# 20     9/1/2019 13:37:04  Pegawai / Tendik  25 - 40 th
# ...                  ...               ...         ...
# 2008  9/16/2019 10:45:44              Umum  25 - 40 th
# 2009  9/16/2019 16:07:41            Alumni  25 - 40 th
# 2010  9/16/2019 16:08:51            Alumni     < 25 th
# 2011  9/16/2019 16:09:04            Alumni  25 - 40 th
# 2013   9/17/2019 7:28:30             Dosen     > 40 th
#
#                            Carek  \
# 14     Kadarsah Suryadi (FTI-TI)
# 16     Sigit Puji Santosa (FTMD)
# 18       Deddy Kurniadi (FTI-TF)
# 19     Sigit Puji Santosa (FTMD)
# 20     Kadarsah Suryadi (FTI-TI)
# ...                          ...
# 2008  Edy Tri Baskoro (FMIPA-MA)
# ...

# %%
ax = new_df['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur sample data')
# Out:
# Text(0.5, 1.0, 'Persentase umur sample data')

# %%
ax = new_df['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori sample data')
# Out:
# Text(0.5, 1.0, 'Persentase kategori sample data')

# %%
count = new_df['Alasan'].value_counts()
alasan = new_df[new_df['Alasan'].isin(count[count > 3].index)]
alasan.sample(5)
# Out:
#                Timestamp   Kategori        Umur                      Carek  \
# 821    9/3/2019 10:26:40     Alumni  25 - 40 th    Tutuka Ariaji (FTTM-TM)
# 1272   9/3/2019 18:31:52     Alumni     < 25 th    Khairurrijal (FMIPA-FI)
# 1664    9/5/2019 7:59:02      Dosen     > 40 th  Sigit Puji Santosa (FTMD)
# 1565   9/4/2019 15:15:00  Mahasiswa     < 25 th  Kadarsah Suryadi (FTI-TI)
# 1922  9/14/2019 16:17:30       Umum  25 - 40 th  Dicky Rezady Munaf (FSRD)
#
#                                                  Alasan Harapan
# 821   Kapabilitas ybs utk memajukan riset dan indust...     NaN
# 1272                            Akhlak dan budi pekerti     NaN
# 1664  Kapabilitas ybs utk memajukan riset dan indust...     NaN
# 1565       Sesuai dengan kriteria kekinian (Rektor 4.0)     NaN
# 1922  Kapabilitas ybs utk memajukan riset dan indust...     NaN

# %%
chart = alasan['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan ')
# Out:
# Text(0.5, 1.0, 'Alasan ')

# %%
new_df['Carek'].value_counts()
# Out:
# Kadarsah Suryadi (FTI-TI)     322
# Tutuka Ariaji (FTTM-TM)       280
# Acep Purqon (FMIPA-FI)        240
# Edy Tri Baskoro (FMIPA-MA)    209
# Khairurrijal (FMIPA-FI)       129
# Dicky Rezady Munaf (FSRD)     112
# Emir Mauludi Husni (STEI)      96
# Sigit Puji Santosa (FTMD)      93
# Deddy Kurniadi (FTI-TF)        91
# Name: Carek, dtype: int64

# %%
Kadarsah = new_df[new_df.Carek == 'Kadarsah Suryadi (FTI-TI)']
Tutuka = new_df[new_df.Carek == 'Tutuka Ariaji (FTTM-TM)']
Acep = new_df[new_df.Carek == 'Acep Purqon (FMIPA-FI)']
Edy = new_df[new_df.Carek == 'Edy Tri Baskoro (FMIPA-MA)']
ijal = new_df[new_df.Carek == 'Khairurrijal (FMIPA-FI)']
Dicky = new_df[new_df.Carek == 'Dicky Rezady Munaf (FSRD)']
Husni = new_df[new_df.Carek == 'Emir Mauludi Husni (STEI)']
Sigit = new_df[new_df.Carek == 'Sigit Puji Santosa (FTMD)']
Deddy = new_df[new_df.Carek == 'Deddy Kurniadi (FTI-TF)']

# %%
Kadarsah.sample(5)
# Out:
#               Timestamp          Kategori        Umur  \
# 1700  9/5/2019 18:42:42            Alumni  25 - 40 th
# 886   9/3/2019 11:37:53              Umum     > 40 th
# 1089  9/3/2019 14:42:06  Pegawai / Tendik     > 40 th
# 962   9/3/2019 13:26:05  Pegawai / Tendik  25 - 40 th
# 1372  9/3/2019 21:59:29            Alumni  25 - 40 th
#
#                           Carek  \
# 1700  Kadarsah Suryadi (FTI-TI)
# 886   Kadarsah Suryadi (FTI-TI)
# 1089  Kadarsah Suryadi (FTI-TI)
# 962   Kadarsah Suryadi (FTI-TI)
# 1372  Kadarsah Suryadi (FTI-TI)
#
#                                                  Alasan  \
# 1700  Kapabilitas ybs utk memajukan riset dan indust...
# 886                           Keberhasilan dan prestasi
# 1089  Program ybs utk peningkatan income dan kesejah...
# 962   Program ybs utk peningkatan income dan kesejah...
# 1372       Kapabilitas ybs utk meningkatkan ranking ITB
#
#                                                 Harapan
# ...

# %%
ax = Kadarsah['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Kadarsah Suryadi')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Kadarsah Suryadi')

# %%
ax = Kadarsah['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Kadarsah Suryadi')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Kadarsah Suryadi')

# %%
count_kadarsah = Kadarsah['Alasan'].value_counts()
alasan_kadarsah = Kadarsah[Kadarsah['Alasan'].isin(count_kadarsah[count_kadarsah > 3].index)]
alasan_kadarsah.sample(5)
# Out:
#               Timestamp          Kategori        Umur  \
# 993   9/3/2019 13:38:13              Umum  25 - 40 th
# 1096  9/3/2019 14:44:45  Pegawai / Tendik  25 - 40 th
# 1016  9/3/2019 13:53:15             Dosen     > 40 th
# 1077  9/3/2019 14:39:13  Pegawai / Tendik  25 - 40 th
# 1089  9/3/2019 14:42:06  Pegawai / Tendik     > 40 th
#
#                           Carek  \
# 993   Kadarsah Suryadi (FTI-TI)
# 1096  Kadarsah Suryadi (FTI-TI)
# 1016  Kadarsah Suryadi (FTI-TI)
# 1077  Kadarsah Suryadi (FTI-TI)
# 1089  Kadarsah Suryadi (FTI-TI)
#
#                                                  Alasan Harapan
# 993                                  Muda dan berenergi     NaN
# 1096  Program ybs utk peningkatan income dan kesejah...     NaN
# 1016                            Akhlak dan budi pekerti     NaN
# 1077  Program ybs utk peningkatan income dan kesejah...     NaN
# 1089  Program ybs utk peningkatan income dan kesejah...     NaN

# %%
chart = alasan_kadarsah['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Kadarsah Suryadi sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Kadarsah Suryadi sebagai CaRek')

# %%
Tutuka.sample(5)
# Out:
#               Timestamp          Kategori     Umur                    Carek  \
# 1191  9/3/2019 16:42:25            Alumni  > 40 th  Tutuka Ariaji (FTTM-TM)
# 775    9/3/2019 9:17:05            Alumni  > 40 th  Tutuka Ariaji (FTTM-TM)
# 728    9/3/2019 8:08:58            Alumni  < 25 th  Tutuka Ariaji (FTTM-TM)
# 725    9/3/2019 8:05:02            Alumni  < 25 th  Tutuka Ariaji (FTTM-TM)
# 928   9/3/2019 12:45:29  Pegawai / Tendik  > 40 th  Tutuka Ariaji (FTTM-TM)
#
#                                                  Alasan  \
# 1191                          Keberhasilan dan prestasi
# 775                Karakter kepemimpinan dan leadership
# 728                Karakter kepemimpinan dan leadership
# 725   Tipe yg futuristik dan outside-the-box yg bisa...
# 928        Kapabilitas ybs utk meningkatkan ranking ITB
#
#                                                 Harapan
# 1191                                                NaN
# 775      ITB makin unggul di kancah regional dan global
# ...

# %%
ax = Tutuka['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Tutuka Ariaji')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Tutuka Ariaji')

# %%
ax = Tutuka['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Edy Tutuka Ariaji')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Edy Tutuka Ariaji')

# %%
count_tutuka = Tutuka['Alasan'].value_counts()
alasan_tutuka = Tutuka[Tutuka['Alasan'].isin(count_tutuka[count_tutuka > 3].index)]
alasan_tutuka.sample(5)
# Out:
#                Timestamp Kategori        Umur                    Carek  \
# 640     9/3/2019 6:42:08    Dosen  25 - 40 th  Tutuka Ariaji (FTTM-TM)
# 1431    9/4/2019 4:47:48   Alumni  25 - 40 th  Tutuka Ariaji (FTTM-TM)
# 1188   9/3/2019 16:37:25   Alumni     > 40 th  Tutuka Ariaji (FTTM-TM)
# 606     9/3/2019 6:10:55   Alumni  25 - 40 th  Tutuka Ariaji (FTTM-TM)
# 2001  9/15/2019 18:24:27   Alumni     < 25 th  Tutuka Ariaji (FTTM-TM)
#
#                                             Alasan  \
# 640           Karakter kepemimpinan dan leadership
# 1431          Karakter kepemimpinan dan leadership
# 1188                     Keberhasilan dan prestasi
# 606   Kapabilitas ybs utk meningkatkan ranking ITB
# 2001                     Keberhasilan dan prestasi
#
#                                    Harapan
# 640                                    NaN
# 1431                        ITB numero uno
# 1188                                   NaN
# 606   Semoga Pak Tutuka menjadi rektor ITB
# ...

# %%
chart = alasan_tutuka['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Tutuka Ariaji sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Tutuka Ariaji sebagai CaRek')

# %%
Acep.sample(5)
# Out:
#               Timestamp   Kategori        Umur                   Carek  \
# 96    9/1/2019 15:24:53      Dosen  25 - 40 th  Acep Purqon (FMIPA-FI)
# 1826   9/9/2019 8:39:07     Alumni  25 - 40 th  Acep Purqon (FMIPA-FI)
# 1489   9/4/2019 9:49:12  Mahasiswa  25 - 40 th  Acep Purqon (FMIPA-FI)
# 28    9/1/2019 14:03:04  Mahasiswa  25 - 40 th  Acep Purqon (FMIPA-FI)
# 910   9/3/2019 12:03:03       Umum  25 - 40 th  Acep Purqon (FMIPA-FI)
#
#                                                  Alasan Harapan
# 96    Mendatangkan dana riset dan kerjasama eksterna...     NaN
# 1826  Kapabilitas ybs utk memajukan riset dan indust...     NaN
# 1489       Sesuai dengan kriteria kekinian (Rektor 4.0)     NaN
# 28                 Karakter kepemimpinan dan leadership     NaN
# 910        Sesuai dengan kriteria kekinian (Rektor 4.0)     NaN

# %%
ax = Acep['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Acep Purqon')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Acep Purqon')

# %%
ax = Acep['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Acep Purqon')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Acep Purqon')

# %%
count_acep = Acep['Alasan'].value_counts()
alasan_acep = Acep[Acep['Alasan'].isin(count_acep[count_acep > 3].index)]
alasan_acep.sample(5)
# Out:
#               Timestamp Kategori        Umur                   Carek  \
# 80    9/1/2019 14:56:45   Alumni  25 - 40 th  Acep Purqon (FMIPA-FI)
# 191   9/1/2019 18:44:56   Alumni     > 40 th  Acep Purqon (FMIPA-FI)
# 1471   9/4/2019 9:00:18     Umum     > 40 th  Acep Purqon (FMIPA-FI)
# 88    9/1/2019 15:11:29     Umum     > 40 th  Acep Purqon (FMIPA-FI)
# 53    9/1/2019 14:29:47     Umum  25 - 40 th  Acep Purqon (FMIPA-FI)
#
#                                             Alasan  \
# 80    Sesuai dengan kriteria kekinian (Rektor 4.0)
# 191                             Muda dan berenergi
# 1471                     Keberhasilan dan prestasi
# 88                              Muda dan berenergi
# 53                       Keberhasilan dan prestasi
#
#                                     Harapan
# 80                                      NaN
# 191   ITB maju ditangan rektor muda. Aamiin
# 1471                                    NaN
# 88                                      NaN
# ...

# %%
chart = alasan_acep['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Acep Purqon sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Acep Purqon sebagai CaRek')

# %%
Edy.sample(5)
# Out:
#               Timestamp          Kategori        Umur  \
# 1759   9/6/2019 9:09:03  Pegawai / Tendik     > 40 th
# 1381  9/3/2019 22:12:55         Mahasiswa     < 25 th
# 458   9/2/2019 18:30:33             Dosen  25 - 40 th
# 432   9/2/2019 18:05:33             Dosen  25 - 40 th
# 1641  9/4/2019 22:27:15              Umum     > 40 th
#
#                            Carek  \
# 1759  Edy Tri Baskoro (FMIPA-MA)
# 1381  Edy Tri Baskoro (FMIPA-MA)
# 458   Edy Tri Baskoro (FMIPA-MA)
# 432   Edy Tri Baskoro (FMIPA-MA)
# 1641  Edy Tri Baskoro (FMIPA-MA)
#
#                                                  Alasan  \
# 1759  Program ybs utk peningkatan income dan kesejah...
# 1381                          Keberhasilan dan prestasi
# 458                           Keberhasilan dan prestasi
# 432                           Keberhasilan dan prestasi
# 1641  Tipe yg futuristik dan outside-the-box yg bisa...
#
#                                                 Harapan
# ...

# %%
ax = Edy['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_title('Persentase umur data pendukung Edy Tri Baskoro')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = Edy['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_title('Persentase kategori data pendukung Edy Tri Baskoro')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
count_Edy = Edy['Alasan'].value_counts()
alasan_Edy = Edy[Edy['Alasan'].isin(count_Edy[count_Edy > 3].index)]
alasan_Edy.head(5)
# Out:
#              Timestamp   Kategori        Umur                       Carek  \
# 84   9/1/2019 15:05:35     Alumni  25 - 40 th  Edy Tri Baskoro (FMIPA-MA)
# 187  9/1/2019 18:34:36      Dosen     > 40 th  Edy Tri Baskoro (FMIPA-MA)
# 219  9/1/2019 22:09:01  Mahasiswa     < 25 th  Edy Tri Baskoro (FMIPA-MA)
# 249   9/2/2019 8:34:46      Dosen  25 - 40 th  Edy Tri Baskoro (FMIPA-MA)
# 254   9/2/2019 8:40:04  Mahasiswa     < 25 th  Edy Tri Baskoro (FMIPA-MA)
#
#                                            Alasan  \
# 84           Karakter kepemimpinan dan leadership
# 187  Kapabilitas ybs utk meningkatkan ranking ITB
# 219                     Keberhasilan dan prestasi
# 249                     Keberhasilan dan prestasi
# 254  Sesuai dengan kriteria kekinian (Rektor 4.0)
#
#                                                Harapan
# 84   Semoga ITB senantiasa menjadi Perguruan tinggi...
# 187                                                NaN
# ...

# %%
chart = alasan_Edy['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Edy Tri Baskoro sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Edy Tri Baskoro sebagai CaRek')

# %%
ijal.sample(5)
# Out:
#               Timestamp   Kategori        Umur                    Carek  \
# 1697  9/5/2019 16:02:41       Umum     < 25 th  Khairurrijal (FMIPA-FI)
# 1484   9/4/2019 9:46:14       Umum     > 40 th  Khairurrijal (FMIPA-FI)
# 931   9/3/2019 12:55:25       Umum     > 40 th  Khairurrijal (FMIPA-FI)
# 1273  9/3/2019 18:32:14     Alumni  25 - 40 th  Khairurrijal (FMIPA-FI)
# 1417   9/4/2019 4:25:23  Mahasiswa     > 40 th  Khairurrijal (FMIPA-FI)
#
#                                                  Alasan         Harapan
# 1697                          Keberhasilan dan prestasi             NaN
# 1484         Kecerdasan dan keberanian utk kemajuan ITB             NaN
# 931                           Keberhasilan dan prestasi  ITB makin jaya
# 1273                          Keberhasilan dan prestasi             NaN
# 1417  Kapabilitas ybs utk memajukan riset dan indust...             NaN

# %%
ax = ijal['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data Khairurrijal')
# Out:
# Text(0.5, 1.0, 'Persentase umur data Khairurrijal')

# %%
ax = ijal['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data Khairurrijal')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data Khairurrijal')

# %%
chart = ijal['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Khairurrijal sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Khairurrijal sebagai CaRek')

# %%
Dicky.sample(5)
# Out:
#                Timestamp          Kategori        Umur  \
# 1985   9/15/2019 9:03:02              Umum     > 40 th
# 2011  9/16/2019 16:09:04            Alumni  25 - 40 th
# 1921  9/14/2019 16:15:23  Pegawai / Tendik  25 - 40 th
# 1992  9/15/2019 10:16:23              Umum     > 40 th
# 1994  9/15/2019 11:08:14              Umum  25 - 40 th
#
#                           Carek  \
# 1985  Dicky Rezady Munaf (FSRD)
# 2011  Dicky Rezady Munaf (FSRD)
# 1921  Dicky Rezady Munaf (FSRD)
# 1992  Dicky Rezady Munaf (FSRD)
# 1994  Dicky Rezady Munaf (FSRD)
#
#                                                  Alasan  \
# 1985                          Keberhasilan dan prestasi
# 2011         Kecerdasan dan keberanian utk kemajuan ITB
# 1921  Tipe yg futuristik dan outside-the-box yg bisa...
# 1992         Kecerdasan dan keberanian utk kemajuan ITB
# 1994               Karakter kepemimpinan dan leadership
#
#                                                 Harapan
# ...

# %%
ax = Dicky['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Dicky Rezady Munaf Supangkat')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Dicky Rezady Munaf Supangkat')

# %%
ax = Dicky['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Dicky Rezady Munaf Supangkat')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Dicky Rezady Munaf Supangkat')

# %%
chart = Dicky['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Dicky Rezady Munaf sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Dicky Rezady Munaf sebagai CaRek')

# %%
Husni.sample(5)
# Out:
#               Timestamp Kategori     Umur                      Carek  \
# 1778   9/7/2019 5:59:46   Alumni  > 40 th  Emir Mauludi Husni (STEI)
# 283   9/2/2019 10:25:18    Dosen  > 40 th  Emir Mauludi Husni (STEI)
# 265    9/2/2019 9:32:34     Umum  > 40 th  Emir Mauludi Husni (STEI)
# 237    9/2/2019 7:52:45     Umum  > 40 th  Emir Mauludi Husni (STEI)
# 293   9/2/2019 11:09:46     Umum  > 40 th  Emir Mauludi Husni (STEI)
#
#                                                  Alasan  \
# 1778         Kecerdasan dan keberanian utk kemajuan ITB
# 283   Kapabilitas ybs utk memajukan riset dan indust...
# 265          Kecerdasan dan keberanian utk kemajuan ITB
# 237          Kecerdasan dan keberanian utk kemajuan ITB
# 293          Kecerdasan dan keberanian utk kemajuan ITB
#
#                                   Harapan
# 1778                                  NaN
# 283                                   NaN
# 265                                   NaN
# ...

# %%
ax = Emir['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Emir Mauludi Husni')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Emir Mauludi Husni')

# %%
ax = Emir['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Emir Mauludi Husni')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Emir Mauludi Husni')

# %%
chart = Emir['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan Emir Mauludi Husni sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan Emir Mauludi Husni sebagai CaRek')

# %%
Sigit.sample(5)
# Out:
#               Timestamp Kategori        Umur                      Carek  \
# 794    9/3/2019 9:39:30     Umum     > 40 th  Sigit Puji Santosa (FTMD)
# 227    9/2/2019 3:31:13    Dosen     > 40 th  Sigit Puji Santosa (FTMD)
# 1664   9/5/2019 7:59:02    Dosen     > 40 th  Sigit Puji Santosa (FTMD)
# 1432   9/4/2019 5:03:53     Umum  25 - 40 th  Sigit Puji Santosa (FTMD)
# 1284  9/3/2019 18:42:34     Umum     > 40 th  Sigit Puji Santosa (FTMD)
#
#                                                  Alasan  \
# 794          Kecerdasan dan keberanian utk kemajuan ITB
# 227   Kapabilitas ybs utk memajukan riset dan indust...
# 1664  Kapabilitas ybs utk memajukan riset dan indust...
# 1432                          Keberhasilan dan prestasi
# 1284  Tipe yg futuristik dan outside-the-box yg bisa...
#
#                                                 Harapan
# 794   Smg dg kepemimpinan P Sigit Puji Santosa ITB m...
# 227                                                 NaN
# ...

# %%
ax = Sigit['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Sigit Puji Santosa')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Sigit Puji Santosa')

# %%
ax = Sigit['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Sigit Puji Santosa')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Sigit Puji Santosa')

# %%
chart = Sigit['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Sigit Puji Santosa sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Sigit Puji Santosa sebagai CaRek')

# %%
Deddy.sample(5)
# Out:
#               Timestamp Kategori        Umur                    Carek  \
# 18    9/1/2019 13:11:56    Dosen  25 - 40 th  Deddy Kurniadi (FTI-TF)
# 454   9/2/2019 18:28:33   Alumni     > 40 th  Deddy Kurniadi (FTI-TF)
# 491   9/2/2019 19:38:35   Alumni     > 40 th  Deddy Kurniadi (FTI-TF)
# 309   9/2/2019 12:59:30   Alumni     > 40 th  Deddy Kurniadi (FTI-TF)
# 1256  9/3/2019 18:17:57   Alumni     > 40 th  Deddy Kurniadi (FTI-TF)
#
#                                                  Alasan  \
# 18    Mendatangkan dana riset dan kerjasama eksterna...
# 454   Kapabilitas ybs utk memajukan riset dan indust...
# 491          Kecerdasan dan keberanian utk kemajuan ITB
# 309        Kapabilitas ybs utk meningkatkan ranking ITB
# 1256       Kapabilitas ybs utk meningkatkan ranking ITB
#
#                                                 Harapan
# 18                                                  NaN
# 454                                                 NaN
# ...

# %%
ax = Deddy['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Deddy Kurniadi')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Deddy Kurniadi')

# %%
ax = Deddy['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Deddy Kurniadi')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Deddy Kurniadi')

# %%
chart = Deddy['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Deddy Kurniadi CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Deddy Kurniadi CaRek')
