# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
df  = pd.read_csv('pilrek.csv')
df.columns = ['Timestamp', 'Kategori', 'Umur', 'Carek', 'Alasan', 'Harapan']

# %%
count_df = df['Carek'].value_counts()
new_df = df[df['Carek'].isin(count_df[count_df > count_df.mean()].index)]
new_df
# Out:
#               Timestamp          Kategori        Umur  \
# 1      9/1/2019 8:33:56            Alumni     > 40 th
# 2      9/1/2019 8:59:43              Umum  25 - 40 th
# 3      9/1/2019 9:26:44  Pegawai / Tendik     > 40 th
# 5     9/1/2019 12:26:46  Pegawai / Tendik  25 - 40 th
# 6     9/1/2019 12:27:13            Alumni     > 40 th
# ..                  ...               ...         ...
# 929  9/14/2019 17:07:49            Alumni     > 40 th
# 935  9/14/2019 20:47:54              Umum     > 40 th
# 944  9/15/2019 14:24:17            Alumni  25 - 40 th
# 951   9/16/2019 8:27:20             Dosen     > 40 th
# 953   9/17/2019 9:52:24  Pegawai / Tendik     > 40 th
#
#                               Carek  \
# 1     Suhono Harso Supangkat (STEI)
# 2     Suhono Harso Supangkat (STEI)
# 3     Suhono Harso Supangkat (STEI)
# 5     Suhono Harso Supangkat (STEI)
# 6     Suhono Harso Supangkat (STEI)
# ..                              ...
# 929          Acep Purqon (FMIPA-FI)
# ...

# %%
ax = new_df['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur sample data')
# Out:
# Text(0.5, 1.0, 'Persentase umur sample data')

# %%
ax = new_df['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori sample data')
# Out:
# Text(0.5, 1.0, 'Persentase kategori sample data')

# %%
count = new_df['Alasan'].value_counts()
alasan = new_df[new_df['Alasan'].isin(count[count > 3].index)]
alasan.sample(5)
# Out:
#               Timestamp          Kategori        Umur  \
# 421   9/3/2019 16:31:19              Umum  25 - 40 th
# 761  9/10/2019 13:29:19            Alumni  25 - 40 th
# 619    9/5/2019 8:35:10  Pegawai / Tendik  25 - 40 th
# 556   9/4/2019 13:35:09             Dosen     > 40 th
# 27    9/1/2019 14:31:36             Dosen  25 - 40 th
#
#                               Carek  \
# 421          Acep Purqon (FMIPA-FI)
# 761  I Nyoman Pugeg Aryantha (SITH)
# 619      Edy Tri Baskoro (FMIPA-MA)
# 556      Edy Tri Baskoro (FMIPA-MA)
# 27           Acep Purqon (FMIPA-FI)
#
#                                                 Alasan  \
# 421               Karakter kepemimpinan dan leadership
# 761  Kapabilitas ybs utk memajukan riset dan indust...
# 619               Karakter kepemimpinan dan leadership
# 556       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 27   Kapabilitas ybs utk memajukan riset dan indust...
#
#                                                Harapan
# ...

# %%
chart = alasan['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan ')
# Out:
# Text(0.5, 1.0, 'Alasan ')

# %%
new_df['Carek'].value_counts()
# Out:
# Acep Purqon (FMIPA-FI)              277
# Edy Tri Baskoro (FMIPA-MA)          200
# I Nyoman Pugeg Aryantha (SITH)      107
# Emir Mauludi Husni (STEI)            46
# Dwi Larso (SBM / President Univ)     43
# Suhono Harso Supangkat (STEI)        37
# Name: Carek, dtype: int64

# %%
Acep = new_df[new_df.Carek == 'Acep Purqon (FMIPA-FI)']
Edy = new_df[new_df.Carek == 'Edy Tri Baskoro (FMIPA-MA)']
Pugeg = new_df[new_df.Carek == 'I Nyoman Pugeg Aryantha (SITH)']
Husni = new_df[new_df.Carek == 'Emir Mauludi Husni (STEI)']
Larso = new_df[new_df.Carek == 'Dwi Larso (SBM / President Univ)']
Harso = new_df[new_df.Carek == 'Suhono Harso Supangkat (STEI)']

# %%
Acep
# Out:
#               Timestamp   Kategori        Umur                   Carek  \
# 11    9/1/2019 14:00:20     Alumni  25 - 40 th  Acep Purqon (FMIPA-FI)
# 13    9/1/2019 14:01:54  Mahasiswa     < 25 th  Acep Purqon (FMIPA-FI)
# 14    9/1/2019 14:02:17  Mahasiswa     < 25 th  Acep Purqon (FMIPA-FI)
# 15    9/1/2019 14:02:39     Alumni     < 25 th  Acep Purqon (FMIPA-FI)
# 17    9/1/2019 14:05:53  Mahasiswa  25 - 40 th  Acep Purqon (FMIPA-FI)
# ..                  ...        ...         ...                     ...
# 914   9/14/2019 8:16:23      Dosen     > 40 th  Acep Purqon (FMIPA-FI)
# 915   9/14/2019 8:51:13       Umum  25 - 40 th  Acep Purqon (FMIPA-FI)
# 920  9/14/2019 10:48:12       Umum  25 - 40 th  Acep Purqon (FMIPA-FI)
# 922  9/14/2019 14:13:36       Umum  25 - 40 th  Acep Purqon (FMIPA-FI)
# 929  9/14/2019 17:07:49     Alumni     > 40 th  Acep Purqon (FMIPA-FI)
#
#                                                 Alasan  \
# 11   Mendatangkan dana riset dan kerjasama eksterna...
# ...

# %%
ax = Acep['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Acep Purqon')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Acep Purqon')

# %%
ax = Acep['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Acep Purqon')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Acep Purqon')

# %%
count_acep = Acep['Alasan'].value_counts()
alasan_acep = Acep[Acep['Alasan'].isin(count_acep[count_acep > 3].index)]
alasan_acep
# Out:
#               Timestamp   Kategori        Umur                   Carek  \
# 11    9/1/2019 14:00:20     Alumni  25 - 40 th  Acep Purqon (FMIPA-FI)
# 13    9/1/2019 14:01:54  Mahasiswa     < 25 th  Acep Purqon (FMIPA-FI)
# 14    9/1/2019 14:02:17  Mahasiswa     < 25 th  Acep Purqon (FMIPA-FI)
# 15    9/1/2019 14:02:39     Alumni     < 25 th  Acep Purqon (FMIPA-FI)
# 17    9/1/2019 14:05:53  Mahasiswa  25 - 40 th  Acep Purqon (FMIPA-FI)
# ..                  ...        ...         ...                     ...
# 914   9/14/2019 8:16:23      Dosen     > 40 th  Acep Purqon (FMIPA-FI)
# 915   9/14/2019 8:51:13       Umum  25 - 40 th  Acep Purqon (FMIPA-FI)
# 920  9/14/2019 10:48:12       Umum  25 - 40 th  Acep Purqon (FMIPA-FI)
# 922  9/14/2019 14:13:36       Umum  25 - 40 th  Acep Purqon (FMIPA-FI)
# 929  9/14/2019 17:07:49     Alumni     > 40 th  Acep Purqon (FMIPA-FI)
#
#                                                 Alasan  \
# 11   Mendatangkan dana riset dan kerjasama eksterna...
# ...

# %%
chart = alasan_acep['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Acep Purqon sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Acep Purqon sebagai CaRek')

# %%
Edy.sample(5)
# Out:
#              Timestamp   Kategori        Umur                       Carek  \
# 481  9/3/2019 19:47:53      Dosen  25 - 40 th  Edy Tri Baskoro (FMIPA-MA)
# 504   9/4/2019 4:19:24       Umum     > 40 th  Edy Tri Baskoro (FMIPA-MA)
# 590  9/4/2019 17:45:32      Dosen     > 40 th  Edy Tri Baskoro (FMIPA-MA)
# 430  9/3/2019 17:14:47       Umum     > 40 th  Edy Tri Baskoro (FMIPA-MA)
# 328  9/2/2019 19:46:09  Mahasiswa     < 25 th  Edy Tri Baskoro (FMIPA-MA)
#
#                                                 Alasan  \
# 481       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 504       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 590  Tipe yg futuristik dan outside-the-box yg bisa...
# 430         Kecerdasan dan keberanian utk kemajuan ITB
# 328  Tipe yg futuristik dan outside-the-box yg bisa...
#
#                                                Harapan
# 481                                     Semoga berjaya
# 504  Semoga bisa membawa ITB menjadi perguruan ting...
# ...

# %%
ax = Edy['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Edy Tri Baskoro')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Edy Tri Baskoro')

# %%
ax = Edy['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Edy Tri Baskoro')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Edy Tri Baskoro')

# %%
count_edy = Edy['Alasan'].value_counts()
alasan_edy = Edy[Edy['Alasan'].isin(count_edy[count_edy > 3].index)]
alasan_edy.sample(5)
# Out:
#              Timestamp Kategori     Umur                       Carek  \
# 433  9/3/2019 17:16:24     Umum  > 40 th  Edy Tri Baskoro (FMIPA-MA)
# 345  9/2/2019 21:00:48   Alumni  > 40 th  Edy Tri Baskoro (FMIPA-MA)
# 375   9/3/2019 8:33:08    Dosen  > 40 th  Edy Tri Baskoro (FMIPA-MA)
# 418  9/3/2019 16:22:49     Umum  > 40 th  Edy Tri Baskoro (FMIPA-MA)
# 315  9/2/2019 18:29:14   Alumni  > 40 th  Edy Tri Baskoro (FMIPA-MA)
#
#                                    Alasan  \
# 433  Karakter kepemimpinan dan leadership
# 345             Keberhasilan dan prestasi
# 375             Keberhasilan dan prestasi
# 418               Akhlak dan budi pekerti
# 315  Karakter kepemimpinan dan leadership
#
#                                                Harapan
# 433  Semoga Pak Edy bisa menjadikan ITB lebih maju ...
# 345                                                NaN
# 375                           . Sukses pak Tri baskoro
# 418  Dengan Kepemimpinan Prof Edy Tri Baskoro sebag...
# ...

# %%
chart = alasan_edy['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Edy Tri Baskoro sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Edy Tri Baskoro sebagai CaRek')

# %%
Pugeg.sample(5)
# Out:
#               Timestamp Kategori        Umur                           Carek  \
# 885   9/13/2019 9:06:45   Alumni  25 - 40 th  I Nyoman Pugeg Aryantha (SITH)
# 761  9/10/2019 13:29:19   Alumni  25 - 40 th  I Nyoman Pugeg Aryantha (SITH)
# 791  9/10/2019 18:53:09    Dosen  25 - 40 th  I Nyoman Pugeg Aryantha (SITH)
# 751  9/10/2019 10:23:43   Alumni  25 - 40 th  I Nyoman Pugeg Aryantha (SITH)
# 779  9/10/2019 16:12:19   Alumni  25 - 40 th  I Nyoman Pugeg Aryantha (SITH)
#
#                                                 Alasan  \
# 885                          Keberhasilan dan prestasi
# 761  Kapabilitas ybs utk memajukan riset dan indust...
# 791                            Akhlak dan budi pekerti
# 751  Kapabilitas ybs utk memajukan riset dan indust...
# 779  Kapabilitas ybs utk memajukan riset dan indust...
#
#                                                Harapan
# 885                                      Memajukan ITB
# 761                                                NaN
# ...

# %%
ax = Pugeg['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung I Nyoman Pugeg Aryantha')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung I Nyoman Pugeg Aryantha')

# %%
ax = Pugeg['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung I Nyoman Pugeg Aryantha')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung I Nyoman Pugeg Aryantha')

# %%
count_pugeg = Pugeg['Alasan'].value_counts()
alasan_pugeg = Pugeg[Pugeg['Alasan'].isin(count_pugeg[count_pugeg > 3].index)]
alasan_pugeg.sample(5)
# Out:
#               Timestamp   Kategori        Umur  \
# 748  9/10/2019 10:22:14     Alumni  25 - 40 th
# 785  9/10/2019 16:53:03  Mahasiswa     < 25 th
# 840   9/12/2019 8:36:18  Mahasiswa     < 25 th
# 745  9/10/2019 10:05:09       Umum     > 40 th
# 879   9/13/2019 6:59:44     Alumni  25 - 40 th
#
#                               Carek  \
# 748  I Nyoman Pugeg Aryantha (SITH)
# 785  I Nyoman Pugeg Aryantha (SITH)
# 840  I Nyoman Pugeg Aryantha (SITH)
# 745  I Nyoman Pugeg Aryantha (SITH)
# 879  I Nyoman Pugeg Aryantha (SITH)
#
#                                                 Alasan  \
# 748                            Akhlak dan budi pekerti
# 785  Kapabilitas ybs utk memajukan riset dan indust...
# 840       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 745  Kapabilitas ybs utk memajukan riset dan indust...
# 879  Kapabilitas ybs utk memajukan riset dan indust...
#
#                                                Harapan
# 748                                                NaN
# ...

# %%
chart = alasan_pugeg['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih I Nyoman Pugeg Aryantha sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih I Nyoman Pugeg Aryantha sebagai CaRek')

# %%
Husni.sample(5)
# Out:
#              Timestamp Kategori     Umur                      Carek  \
# 564  9/4/2019 14:32:20     Umum  < 25 th  Emir Mauludi Husni (STEI)
# 133  9/1/2019 18:48:06   Alumni  > 40 th  Emir Mauludi Husni (STEI)
# 309  9/2/2019 18:14:48   Alumni  > 40 th  Emir Mauludi Husni (STEI)
# 235   9/2/2019 8:16:29   Alumni  > 40 th  Emir Mauludi Husni (STEI)
# 562  9/4/2019 14:18:19   Alumni  < 25 th  Emir Mauludi Husni (STEI)
#
#                                                 Alasan  \
# 564                          Keberhasilan dan prestasi
# 133  Kapabilitas ybs utk memajukan riset dan indust...
# 309  Tipe yg futuristik dan outside-the-box yg bisa...
# 235         Kecerdasan dan keberanian utk kemajuan ITB
# 562  Tipe yg futuristik dan outside-the-box yg bisa...
#
#                                                Harapan
# 564                                     Makin baik itb
# 133                ITB bisa membawa RI lebih baik lagi
# 309  Membangun ITB dengan mahasiswa yang bermental ...
# ...

# %%
ax = Husni['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_title('Persentase umur data pendukung Emir Mauludi Husni')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = Husni['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_title('Persentase kategori data pendukung Emir Mauludi Husni')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
count_husni = Husni['Alasan'].value_counts()
alasan_husni = Husni[Husni['Alasan'].isin(count_husni[count_husni > 3].index)]
alasan_husni.head(5)
# Out:
#              Timestamp Kategori     Umur                      Carek  \
# 91   9/1/2019 16:37:04   Alumni  > 40 th  Emir Mauludi Husni (STEI)
# 133  9/1/2019 18:48:06   Alumni  > 40 th  Emir Mauludi Husni (STEI)
# 148  9/1/2019 19:34:02   Alumni  > 40 th  Emir Mauludi Husni (STEI)
# 177  9/1/2019 21:23:24   Alumni  > 40 th  Emir Mauludi Husni (STEI)
# 195  9/1/2019 22:16:35   Alumni  > 40 th  Emir Mauludi Husni (STEI)
#
#                                                 Alasan  \
# 91   Tipe yg futuristik dan outside-the-box yg bisa...
# 133  Kapabilitas ybs utk memajukan riset dan indust...
# 148       Kapabilitas ybs utk meningkatkan ranking ITB
# 177  Kapabilitas ybs utk memajukan riset dan indust...
# 195  Kapabilitas ybs utk memajukan riset dan indust...
#
#                                                Harapan
# 91   Mampu membawa itb kerjasama dengan industri. M...
# 133                ITB bisa membawa RI lebih baik lagi
# 148                                                NaN
# ...

# %%
chart = alasan_husni['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Emir Mauludi Husni sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Emir Mauludi Husni sebagai CaRek')

# %%
Larso.sample(5)
# Out:
#              Timestamp Kategori     Umur                             Carek  \
# 245   9/2/2019 9:45:38   Alumni  > 40 th  Dwi Larso (SBM / President Univ)
# 197  9/1/2019 22:25:26   Alumni  > 40 th  Dwi Larso (SBM / President Univ)
# 181  9/1/2019 21:37:08   Alumni  < 25 th  Dwi Larso (SBM / President Univ)
# 224   9/2/2019 6:58:23   Alumni  > 40 th  Dwi Larso (SBM / President Univ)
# 192  9/1/2019 22:12:07   Alumni  > 40 th  Dwi Larso (SBM / President Univ)
#
#                                                 Alasan  \
# 245  Tipe yg futuristik dan outside-the-box yg bisa...
# 197       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 181               Karakter kepemimpinan dan leadership
# 224       Kapabilitas ybs utk meningkatkan ranking ITB
# 192       Sesuai dengan kriteria kekinian (Rektor 4.0)
#
#                                                Harapan
# 245  ITB menjadi pusat riset telnologi untuk menduk...
# 197  Kurikulum ITB lebih mendekat pada dunia nyata ...
# ...

# %%
ax = Larso['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Dwi Larso')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Dwi Larso')

# %%
ax = Larso['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Dwi Larso')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Dwi Larso')

# %%
chart = Larso['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Dwi Larso sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Dwi Larso sebagai CaRek')

# %%
Harso.sample(5)
# Out:
#              Timestamp          Kategori        Umur  \
# 463  9/3/2019 18:47:19  Pegawai / Tendik  25 - 40 th
# 373   9/3/2019 8:30:41         Mahasiswa     < 25 th
# 371   9/3/2019 8:30:17         Mahasiswa  25 - 40 th
# 455  9/3/2019 18:37:32              Umum  25 - 40 th
# 270  9/2/2019 14:56:40              Umum  25 - 40 th
#
#                              Carek  \
# 463  Suhono Harso Supangkat (STEI)
# 373  Suhono Harso Supangkat (STEI)
# 371  Suhono Harso Supangkat (STEI)
# 455  Suhono Harso Supangkat (STEI)
# 270  Suhono Harso Supangkat (STEI)
#
#                                            Alasan  \
# 463  Sesuai dengan kriteria kekinian (Rektor 4.0)
# 373    Kecerdasan dan keberanian utk kemajuan ITB
# 371          Karakter kepemimpinan dan leadership
# 455  Sesuai dengan kriteria kekinian (Rektor 4.0)
# 270  Sesuai dengan kriteria kekinian (Rektor 4.0)
#
#                                                Harapan
# 463    Mampu membawa perubahan untuk ITB dan Indonesia
# ...

# %%
ax = Harso['Umur'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase umur data pendukung Suhono Harso Supangkat')
# Out:
# Text(0.5, 1.0, 'Persentase umur data pendukung Suhono Harso Supangkat')

# %%
ax = Harso['Kategori'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Persentase kategori data pendukung Suhono Harso Supangkat')
# Out:
# Text(0.5, 1.0, 'Persentase kategori data pendukung Suhono Harso Supangkat')

# %%
chart = Harso['Alasan'].value_counts().plot(kind='bar')
chart.set_xticklabels(chart.get_xticklabels(), rotation=45, horizontalalignment='right')
chart.set_title('Alasan memilih Suhono Harso Supangkat sebagai CaRek')
# Out:
# Text(0.5, 1.0, 'Alasan memilih Suhono Harso Supangkat sebagai CaRek')
