# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df  = pd.read_csv('pilrek.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.tail
# Out:
# <bound method NDFrame.tail of               Timestamp     Kategori Anda Kategori Umur Anda  \
# 0      9/1/2019 7:47:18            Alumni         25 - 40 th
# 1      9/1/2019 8:33:56            Alumni            > 40 th
# 2      9/1/2019 8:59:43              Umum         25 - 40 th
# 3      9/1/2019 9:26:44  Pegawai / Tendik            > 40 th
# 4     9/1/2019 12:25:40             Dosen         25 - 40 th
# 5     9/1/2019 12:26:46  Pegawai / Tendik         25 - 40 th
# 6     9/1/2019 12:27:13            Alumni            > 40 th
# 7     9/1/2019 12:28:42             Dosen         25 - 40 th
# 8     9/1/2019 12:54:47             Dosen         25 - 40 th
# 9     9/1/2019 13:58:03              Umum            > 40 th
# 10    9/1/2019 14:00:04             Dosen            > 40 th
# 11    9/1/2019 14:00:20            Alumni         25 - 40 th
# 12    9/1/2019 14:01:25              Umum         25 - 40 th
# 13    9/1/2019 14:01:54         Mahasiswa            < 25 th
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
milih_mahasiswa = df.loc[df['Kategori Anda'] == 'Mahasiswa']
milih_mahasiswa
# Out:
#               Timestamp Kategori Anda Kategori Umur Anda  \
# 13    9/1/2019 14:01:54     Mahasiswa            < 25 th
# 14    9/1/2019 14:02:17     Mahasiswa            < 25 th
# 17    9/1/2019 14:05:53     Mahasiswa         25 - 40 th
# 18    9/1/2019 14:09:00     Mahasiswa         25 - 40 th
# 22    9/1/2019 14:17:34     Mahasiswa            < 25 th
# 23    9/1/2019 14:20:54     Mahasiswa         25 - 40 th
# 24    9/1/2019 14:22:04     Mahasiswa         25 - 40 th
# 25    9/1/2019 14:23:10     Mahasiswa            < 25 th
# 28    9/1/2019 14:31:55     Mahasiswa         25 - 40 th
# 29    9/1/2019 14:34:43     Mahasiswa            < 25 th
# 30    9/1/2019 14:35:44     Mahasiswa            < 25 th
# 41    9/1/2019 15:06:17     Mahasiswa         25 - 40 th
# 44    9/1/2019 15:09:29     Mahasiswa            < 25 th
# 45    9/1/2019 15:10:34     Mahasiswa            < 25 th
# 64    9/1/2019 15:35:47     Mahasiswa         25 - 40 th
# ...

# %%
ax = milih_mahasiswa['Alasan Memilih CaRek'].value_counts()
ax
# Out:
# Sesuai dengan kriteria kekinian (Rektor 4.0)                                   24
# Keberhasilan dan prestasi                                                      21
# Tipe yg futuristik dan outside-the-box yg bisa menangkap peluang masa depan    20
# Kapabilitas ybs utk memajukan riset dan industri RI                            18
# Muda dan berenergi                                                             17
# Karakter kepemimpinan dan leadership                                           14
# Kecerdasan dan keberanian utk kemajuan ITB                                     14
# Akhlak dan budi pekerti                                                        13
# Mendatangkan dana riset dan kerjasama eksternal, dalam dan luar negeri         11
# Kapabilitas ybs utk meningkatkan ranking ITB                                    8
# Dosen pembimbing                                                                1
# ...

# %%
alasan_4 = ['Kapabilitas ybs utk meningkatkan ranking ITB',
    'Mendatangkan dana riset dan kerjasama eksternal, dalam dan luar negeri', 
'Tipe yg futuristik dan outside-the-box yg bisa menangkap peluang masa depan', 'Kapabilitas ybs utk memajukan riset dan industri RI']

count = []
for alasan in alasan_4:
    for i in range(len(ax)):
        if ax.index[i] == alasan:
            count.append(ax[i])
            break

series_4 = pd.Series(count, index = alasan_4)

# %%
series_4
# Out:
# Kapabilitas ybs utk meningkatkan ranking ITB                                    8
# Mendatangkan dana riset dan kerjasama eksternal, dalam dan luar negeri         11
# Tipe yg futuristik dan outside-the-box yg bisa menangkap peluang masa depan    20
# Kapabilitas ybs utk memajukan riset dan industri RI                            18
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

labels=['Kapabilitas ybs utk meningkatkan ranking ITB',
    'Mendatangkan dana riset dan kerjasama eksternal, dalam dan luar negeri', 
'Tipe yg futuristik dan outside-the-box yg bisa menangkap peluang masa depan', 
        'Kapabilitas ybs utk memajukan riset dan industri RI']
markers = [0, 5, 10, 15, 20, 25]
str_markers = ["0", "5", "10", "15", "20", "25"]

def make_radar_chart(name, stats, attribute_labels = labels, plot_markers = markers):

    labels = np.array(attribute_labels)

    angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False)
    stats = np.concatenate((stats,[stats[0]]))
    angles = np.concatenate((angles,[angles[0]]))

    fig= plt.figure()
    ax = fig.add_subplot(111, polar=True)
    ax.plot(angles, stats, 'o-', linewidth=2)
    ax.fill(angles, stats, alpha=0.25)
    ax.set_thetagrids(angles * 180/np.pi, labels)
    plt.yticks(markers)
    ax.set_title(name)
    ax.grid(True)

plt.show()

# %%
make_radar_chart("Mahasiswa untuk ITB 2045", series_4)

# %%
milih_umur = df.loc[df['Kategori Umur Anda'] == '< 25 th']
milih_umur
# Out:
#               Timestamp     Kategori Anda Kategori Umur Anda  \
# 13    9/1/2019 14:01:54         Mahasiswa            < 25 th
# 14    9/1/2019 14:02:17         Mahasiswa            < 25 th
# 15    9/1/2019 14:02:39            Alumni            < 25 th
# 19    9/1/2019 14:09:23            Alumni            < 25 th
# 20    9/1/2019 14:13:05              Umum            < 25 th
# 22    9/1/2019 14:17:34         Mahasiswa            < 25 th
# 25    9/1/2019 14:23:10         Mahasiswa            < 25 th
# 29    9/1/2019 14:34:43         Mahasiswa            < 25 th
# 30    9/1/2019 14:35:44         Mahasiswa            < 25 th
# 44    9/1/2019 15:09:29         Mahasiswa            < 25 th
# 45    9/1/2019 15:10:34         Mahasiswa            < 25 th
# 62    9/1/2019 15:30:26            Alumni            < 25 th
# 66    9/1/2019 15:38:18         Mahasiswa            < 25 th
# 76    9/1/2019 16:03:03            Alumni            < 25 th
# ...

# %%
bx = milih_umur['Alasan Memilih CaRek'].value_counts()
bx
# Out:
# Sesuai dengan kriteria kekinian (Rektor 4.0)                                                                              30
# Keberhasilan dan prestasi                                                                                                 26
# Kecerdasan dan keberanian utk kemajuan ITB                                                                                20
# Muda dan berenergi                                                                                                        19
# Tipe yg futuristik dan outside-the-box yg bisa menangkap peluang masa depan                                               19
# Kapabilitas ybs utk memajukan riset dan industri RI                                                                       17
# Akhlak dan budi pekerti                                                                                                   15
# ...

# %%
alasan_2 = ['Sesuai dengan kriteria kekinian (Rektor 4.0)',
    'Muda dan berenergi', 'Tipe yg futuristik dan outside-the-box yg bisa menangkap peluang masa depan']


count = []
for alasan2 in alasan_2:
    for j in range(len(bx)):
        if bx.index[j] == alasan2:
            count.append(bx[j])
            break

series_2 = pd.Series(count, index = alasan_2)

# %%
series_2
# Out:
# Sesuai dengan kriteria kekinian (Rektor 4.0)                                   30
# Muda dan berenergi                                                             19
# Tipe yg futuristik dan outside-the-box yg bisa menangkap peluang masa depan    19
# dtype: int64

# %%
ax = series_2.plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
ax.set_title('Civitas Akademika Milenial untuk ITB 4.0')
# Out:
# Text(0.5, 1.0, 'Civitas Akademika Milenial untuk ITB 4.0')

# %%
milih_acah = df.loc[df['CaRek Pilihan'] == 'Kadarsah Suryadi (FTI-TI)']
milih_acah
# Out:
#               Timestamp     Kategori Anda Kategori Umur Anda  \
# 4     9/1/2019 12:25:40             Dosen         25 - 40 th
# 16    9/1/2019 14:03:29             Dosen            > 40 th
# 106   9/1/2019 17:23:35              Umum            > 40 th
# 109   9/1/2019 17:29:24         Mahasiswa            < 25 th
# 292   9/2/2019 16:03:33         Mahasiswa            < 25 th
# 349   9/2/2019 21:26:59              Umum            > 40 th
# 359    9/3/2019 1:57:21            Alumni            > 40 th
# 452   9/3/2019 18:19:29  Pegawai / Tendik         25 - 40 th
# 660    9/6/2019 6:02:34         Mahasiswa            < 25 th
# 795  9/10/2019 20:20:51         Mahasiswa         25 - 40 th
#
#                  CaRek Pilihan  \
# 4    Kadarsah Suryadi (FTI-TI)
# 16   Kadarsah Suryadi (FTI-TI)
# 106  Kadarsah Suryadi (FTI-TI)
# 109  Kadarsah Suryadi (FTI-TI)
# 292  Kadarsah Suryadi (FTI-TI)
# 349  Kadarsah Suryadi (FTI-TI)
# 359  Kadarsah Suryadi (FTI-TI)
# 452  Kadarsah Suryadi (FTI-TI)
# ...

# %%
dx = milih_acah['Kategori Anda'].value_counts()
dx
# Out:
# Mahasiswa           4
# Dosen               2
# Umum                2
# Alumni              1
# Pegawai / Tendik    1
# Name: Kategori Anda, dtype: int64

# %%
ex= milih_acah['Alasan Memilih CaRek'].value_counts()

# %%
ex
# Out:
# Keberhasilan dan prestasi                                                      3
# Karakter kepemimpinan dan leadership                                           2
# Kapabilitas ybs utk meningkatkan ranking ITB                                   1
# Tipe yg futuristik dan outside-the-box yg bisa menangkap peluang masa depan    1
# rendah hati dan komunikatif                                                    1
# Kecerdasan dan keberanian utk kemajuan ITB                                     1
# Kapabilitas ybs utk memajukan riset dan industri RI                            1
# Name: Alasan Memilih CaRek, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

labels=['Keberhasilan dan prestasi',
    'Karakter kepemimpinan dan leadership', 
'Kapabilitas ybs utk meningkatkan ranking ITB', 
        'Tipe yg futuristik dan outside-the-box yg bisa menangkap peluang masa depan','rendah hati dan komunikatif','Kecerdasan dan keberanian utk kemajuan ITB',
       'Kapabilitas ybs utk memajukan riset dan industri RI']
markers = [0, 0.5, 1, 1.5, 2, 2.5, 3]
str_markers = ["0", "0.5", "1", "1.5", "2", "2.5","3"]

def make_radar_chart2(name, stats, attribute_labels = labels, plot_markers = markers):

    labels = np.array(attribute_labels)

    angles = np.linspace(0, 2*np.pi, len(labels), endpoint=False)
    stats = np.concatenate((stats,[stats[0]]))
    angles = np.concatenate((angles,[angles[0]]))

    fig= plt.figure()
    ax = fig.add_subplot(111, polar=True)
    ax.plot(angles, stats, 'o-', linewidth=2)
    ax.fill(angles, stats, alpha=0.25)
    ax.set_thetagrids(angles * 180/np.pi, labels)
    plt.yticks(markers)
    ax.set_title(name)
    ax.grid(True)

plt.show()

# %%
make_radar_chart2("Tingkat Elektabilitas Pak Acah Menurut Civitas Akademika", ex)
