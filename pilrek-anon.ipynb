# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek-anon.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#           Timestamp     Kategori Anda Kategori Umur Anda  \
# 4  9/1/2019 8:00:33         Mahasiswa            < 25 th
# 5  9/1/2019 8:06:24             Dosen         25 - 40 th
# 6  9/1/2019 8:24:13         Mahasiswa            < 25 th
# 7  9/1/2019 8:33:31             Dosen            > 40 th
# 8  9/1/2019 9:19:59  Pegawai / Tendik            < 25 th
#
#                    CaRek Pilihan  \
# 4     Rangga Handika (Pengusaha)
# 5       Togar M Simatupang (SBM)
# 6        Satria Bijaksana (FTTM)
# 7          Jaka Sembiring (STEI)
# 8  Suhono Harso Supangkat (STEI)
#
#                                 Alasan Memilih CaRek  \
# 4                                 Muda dan berenergi
# 5       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 6                                 Muda dan berenergi
# 7  Tipe yg futuristik dan outside-the-box yg bisa...
# 8       Sesuai dengan kriteria kekinian (Rektor 4.0)
#
#                                         Harapan Anda
# 4  ITB bisa menjadi kampus technopreneur terbaik ...
# 5                                                NaN
# 6                                                NaN
# 7       Dosen lebih diutamakan dibanding pejabat ITB
# 8                                                NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp               0
# Kategori Anda           0
# Kategori Umur Anda      0
# CaRek Pilihan           0
# Alasan Memilih CaRek    0
# Harapan Anda            5
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
