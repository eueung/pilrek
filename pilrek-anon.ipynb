# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek-anon.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#             Timestamp     Kategori Anda Kategori Umur Anda  \
# 52  9/1/2019 14:28:12            Alumni            < 25 th
# 53  9/1/2019 14:29:47              Umum         25 - 40 th
# 54  9/1/2019 14:29:24              Umum         25 - 40 th
# 55  9/1/2019 14:31:36  Pegawai / Tendik         25 - 40 th
# 56  9/1/2019 14:32:02             Dosen            > 40 th
#
#                     CaRek Pilihan  \
# 52         Acep Purqon (FMIPA-FI)
# 53         Acep Purqon (FMIPA-FI)
# 54         Acep Purqon (FMIPA-FI)
# 55         Acep Purqon (FMIPA-FI)
# 56  Suhono Harso Supangkat (STEI)
#
#                                  Alasan Memilih CaRek  \
# 52       Kapabilitas ybs utk meningkatkan ranking ITB
# 53                          Keberhasilan dan prestasi
# 54  Kapabilitas ybs utk memajukan riset dan indust...
# 55       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 56       Sesuai dengan kriteria kekinian (Rektor 4.0)
#
#                                          Harapan Anda
# 52                                                  -
# 53                              Indonesia mendunia...
# 54                                                NaN
# 55  CaRek pilihan saya menjadi rektor ITB yang dap...
# 56                                                NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                0
# Kategori Anda            0
# Kategori Umur Anda       0
# CaRek Pilihan            0
# Alasan Memilih CaRek     0
# Harapan Anda            33
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
