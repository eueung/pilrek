# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek-anon.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#             Timestamp Kategori Anda Kategori Umur Anda  \
# 31  9/1/2019 14:03:36     Mahasiswa            < 25 th
# 32  9/1/2019 14:03:44     Mahasiswa            < 25 th
# 33  9/1/2019 14:03:46     Mahasiswa            < 25 th
# 34  9/1/2019 14:04:00     Mahasiswa            < 25 th
# 35  9/1/2019 14:04:05     Mahasiswa            < 25 th
#
#              CaRek Pilihan                          Alasan Memilih CaRek  \
# 31  Acep Purqon (FMIPA-FI)  Sesuai dengan kriteria kekinian (Rektor 4.0)
# 32  Acep Purqon (FMIPA-FI)  Sesuai dengan kriteria kekinian (Rektor 4.0)
# 33  Acep Purqon (FMIPA-FI)  Sesuai dengan kriteria kekinian (Rektor 4.0)
# 34  Acep Purqon (FMIPA-FI)                            Muda dan berenergi
# 35  Acep Purqon (FMIPA-FI)                     Keberhasilan dan prestasi
#
#                                 Harapan Anda
# 31        Kemajuan ITB yang dapat lebih baik
# 32                                       NaN
# 33                                       NaN
# 34  Kampus ini bisa menerapkan Data Scientis
# 35                                       NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                0
# Kategori Anda            0
# Kategori Umur Anda       0
# CaRek Pilihan            0
# Alasan Memilih CaRek     0
# Harapan Anda            22
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
