# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek-anon.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#             Timestamp Kategori Anda Kategori Umur Anda  \
# 261  9/2/2019 9:25:21        Alumni         25 - 40 th
# 262  9/2/2019 9:28:51          Umum            > 40 th
# 263  9/2/2019 9:28:58         Dosen            > 40 th
# 264  9/2/2019 9:29:46         Dosen            > 40 th
# 265  9/2/2019 9:32:34          Umum            > 40 th
#
#                  CaRek Pilihan  \
# 261     Acep Purqon (FMIPA-FI)
# 262  Emir Mauludi Husni (STEI)
# 263  Emir Mauludi Husni (STEI)
# 264    Deddy Kurniadi (FTI-TF)
# 265  Emir Mauludi Husni (STEI)
#
#                                   Alasan Memilih CaRek  \
# 261       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 262       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 263                          Keberhasilan dan prestasi
# 264  Rektor yang netral, kebangsaan dan berprinsip ...
# 265         Kecerdasan dan keberanian utk kemajuan ITB
#
#                                           Harapan Anda
# 261  semoga bisa terpilih menjadi rektor baru dan b...
# 262                   Pak Emir bisa menjadi rektor ITB
# 263                                          ITB maju
# 264  Rektor yang mampu mengembalikan ITB sebagai ce...
# 265                                                NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            130
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
