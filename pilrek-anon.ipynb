# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek-anon.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#             Timestamp Kategori Anda Kategori Umur Anda  \
# 757  9/3/2019 8:46:10          Umum            > 40 th
# 758  9/3/2019 8:48:57         Dosen            > 40 th
# 759  9/3/2019 8:50:52          Umum            > 40 th
# 760  9/3/2019 8:53:02        Alumni         25 - 40 th
# 761  9/3/2019 8:53:55        Alumni         25 - 40 th
#
#                           CaRek Pilihan  \
# 757          Rangga Handika (Pengusaha)
# 758           Sigit Puji Santosa (FTMD)
# 759  Bramantyo (Direktur PPM Manajemen)
# 760             Tutuka Ariaji (FTTM-TM)
# 761             Tutuka Ariaji (FTTM-TM)
#
#                              Alasan Memilih CaRek  \
# 757                            Muda dan berenergi
# 758                     Keberhasilan dan prestasi
# 759  Sesuai dengan kriteria kekinian (Rektor 4.0)
# 760          Karakter kepemimpinan dan leadership
# 761  Sesuai dengan kriteria kekinian (Rektor 4.0)
#
#                                           Harapan Anda
# 757                               cari calon dari luar
# 758                                                NaN
# 759  Dng kapabilitas ybs sbg manager LPPM dan ybs m...
# 760  Smg rektor yang baru bisa membawa perubahan ag...
# 761                                                NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            377
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
