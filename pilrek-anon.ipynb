# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek-anon.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#             Timestamp Kategori Anda Kategori Umur Anda  \
# 14  9/1/2019 12:26:02         Dosen            > 40 th
# 15  9/1/2019 12:30:22        Alumni         25 - 40 th
# 16  9/1/2019 12:41:27         Dosen            > 40 th
# 17  9/1/2019 13:09:23         Dosen         25 - 40 th
# 18  9/1/2019 13:11:56         Dosen         25 - 40 th
#
#                   CaRek Pilihan  \
# 14    Kadarsah Suryadi (FTI-TI)
# 15  Megawati Santoso (FMIPA-KI)
# 16    Sigit Puji Santosa (FTMD)
# 17      Satria Bijaksana (FTTM)
# 18      Deddy Kurniadi (FTI-TF)
#
#                                  Alasan Memilih CaRek Harapan Anda
# 14                          Keberhasilan dan prestasi          NaN
# 15             Emansipasi, kesetaraan dan kebhinekaan          NaN
# 16  Kapabilitas ybs utk memajukan riset dan indust...          NaN
# 17                                 Muda dan berenergi          NaN
# 18  Mendatangkan dana riset dan kerjasama eksterna...          NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                0
# Kategori Anda            0
# Kategori Umur Anda       0
# CaRek Pilihan            0
# Alasan Memilih CaRek     0
# Harapan Anda            11
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
