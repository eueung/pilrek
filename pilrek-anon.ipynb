# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek-anon.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#              Timestamp Kategori Anda Kategori Umur Anda  \
# 460  9/2/2019 18:31:49        Alumni            < 25 th
# 461  9/2/2019 18:33:06        Alumni            > 40 th
# 462  9/2/2019 18:33:50     Mahasiswa            < 25 th
# 463  9/2/2019 18:34:09     Mahasiswa         25 - 40 th
# 464  9/2/2019 18:36:25     Mahasiswa         25 - 40 th
#
#                        CaRek Pilihan  \
# 460  Mikrajuddin Abdullah (FMIPA-FI)
# 461         Togar M Simatupang (SBM)
# 462        Kadarsah Suryadi (FTI-TI)
# 463  Mikrajuddin Abdullah (FMIPA-FI)
# 464  Mikrajuddin Abdullah (FMIPA-FI)
#
#                                   Alasan Memilih CaRek  \
# 460  Kapabilitas ybs utk memajukan riset dan indust...
# 461         Kecerdasan dan keberanian utk kemajuan ITB
# 462                          Keberhasilan dan prestasi
# 463                          Keberhasilan dan prestasi
# 464                          Keberhasilan dan prestasi
#
#                                           Harapan Anda
# 460                                           Semangat
# 461  Rektor terpilih menjadi roll model yg kuat dal...
# 462                                               Yuhu
# 463                                                NaN
# 464  Semoga rektor yg terpilih dapat membawa itb da...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            233
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
