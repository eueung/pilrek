# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#              Timestamp Kategori Anda Kategori Umur Anda  \
# 313  9/2/2019 18:25:19        Alumni            > 40 th
# 314  9/2/2019 18:27:06        Alumni         25 - 40 th
# 315  9/2/2019 18:29:14        Alumni            > 40 th
# 316  9/2/2019 18:34:18     Mahasiswa            < 25 th
# 317  9/2/2019 18:35:25     Mahasiswa            < 25 th
#
#                   CaRek Pilihan                          Alasan Memilih CaRek  \
# 313  Edy Tri Baskoro (FMIPA-MA)  Sesuai dengan kriteria kekinian (Rektor 4.0)
# 314  Edy Tri Baskoro (FMIPA-MA)  Kapabilitas ybs utk meningkatkan ranking ITB
# 315  Edy Tri Baskoro (FMIPA-MA)          Karakter kepemimpinan dan leadership
# 316  Edy Tri Baskoro (FMIPA-MA)          Karakter kepemimpinan dan leadership
# 317  Edy Tri Baskoro (FMIPA-MA)    Kecerdasan dan keberanian utk kemajuan ITB
#
#                                           Harapan Anda
# 313  Mempersiapkan ITB menghadapi era bisnis dg kar...
# 314  ITB dipimpin oleh rektor yang amanah dan beror...
# 315    Meningkatkan ranking ITB di dunia internasional
# 316  Semoga rektor ITB bisa membawa ITB ke kancah y...
# 317  Semoga ITB bisa lebih berprestasi lagi di bawa...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            104
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
