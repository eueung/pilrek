# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#              Timestamp     Kategori Anda Kategori Umur Anda  \
# 205  9/1/2019 23:34:58            Alumni            > 40 th
# 206  9/1/2019 23:35:05            Alumni         25 - 40 th
# 207  9/1/2019 23:39:08              Umum            < 25 th
# 208   9/2/2019 0:38:15  Pegawai / Tendik            > 40 th
# 209   9/2/2019 0:57:10            Alumni            > 40 th
#
#                         CaRek Pilihan  \
# 205  Dwi Larso (SBM / President Univ)
# 206            Acep Purqon (FMIPA-FI)
# 207       Megawati Santoso (FMIPA-KI)
# 208  Dwi Larso (SBM / President Univ)
# 209  Dwi Larso (SBM / President Univ)
#
#                                   Alasan Memilih CaRek  \
# 205       Kapabilitas ybs utk meningkatkan ranking ITB
# 206  Mendatangkan dana riset dan kerjasama eksterna...
# 207         Kecerdasan dan keberanian utk kemajuan ITB
# 208         Kecerdasan dan keberanian utk kemajuan ITB
# 209         Kecerdasan dan keberanian utk kemajuan ITB
#
#                                           Harapan Anda
# 205                                ITB jauh lebih baik
# 206                                                NaN
# 207                                                NaN
# 208  Mengembangkan ITB sebagai aset NKRI menuju per...
# 209                                                NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                0
# Kategori Anda            0
# Kategori Umur Anda       0
# CaRek Pilihan            0
# Alasan Memilih CaRek     0
# Harapan Anda            70
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
