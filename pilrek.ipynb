# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#              Timestamp Kategori Anda Kategori Umur Anda         CaRek Pilihan  \
# 627  9/5/2019 11:05:29          Umum            > 40 th  Edwan Kardena (FTSL)
# 628  9/5/2019 11:22:07          Umum            > 40 th  Edwan Kardena (FTSL)
# 629  9/5/2019 11:40:20        Alumni            > 40 th  Edwan Kardena (FTSL)
# 630  9/5/2019 11:53:38          Umum            > 40 th  Edwan Kardena (FTSL)
# 631  9/5/2019 12:02:01          Umum         25 - 40 th  Edwan Kardena (FTSL)
#
#                                   Alasan Memilih CaRek  \
# 627       Kapabilitas ybs utk meningkatkan ranking ITB
# 628  Tipe yg futuristik dan outside-the-box yg bisa...
# 629  Tipe yg futuristik dan outside-the-box yg bisa...
# 630       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 631  Kapabilitas ybs utk memajukan riset dan indust...
#
#                                   Harapan Anda
# 627  ITB masuk jajaran institut 10 besar Dunia
# 628   Menjadi perguruan tinggi andalan di Asia
# 629                Maju Ber akhlaqul Karimah j
# 630                             Semoga sukses
# 631         Peningkatan pendidikan anak bangsa

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            191
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
