# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#              Timestamp Kategori Anda Kategori Umur Anda  \
# 715  9/8/2019 17:02:31         Dosen            > 40 th
# 716  9/8/2019 18:32:06         Dosen         25 - 40 th
# 717  9/8/2019 18:56:56     Mahasiswa            < 25 th
# 718  9/8/2019 19:26:08     Mahasiswa            < 25 th
# 719  9/8/2019 23:14:35     Mahasiswa         25 - 40 th
#
#                   CaRek Pilihan  \
# 715      Acep Purqon (FMIPA-FI)
# 716   Sigit Puji Santosa (FTMD)
# 717  Edy Tri Baskoro (FMIPA-MA)
# 718   Sigit Puji Santosa (FTMD)
# 719   Sigit Puji Santosa (FTMD)
#
#                                   Alasan Memilih CaRek  \
# 715  Mendatangkan dana riset dan kerjasama eksterna...
# 716       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 717       Kapabilitas ybs utk meningkatkan ranking ITB
# 718  Kapabilitas ybs utk memajukan riset dan indust...
# 719  Kapabilitas ybs utk memajukan riset dan indust...
#
#                                           Harapan Anda
# 715  Rektor yang energik, kerja keras dan kreatif i...
# 716  ITB1 semoga bisa semakin sukeskan itb bersaing...
# 717  Semoga kualitas ITB bisa jauh lebih baik, teru...
# 718                              Semoga itb lebih baik
# 719  ITB menjadi perguruan tinggi terdepan dan terb...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            218
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
