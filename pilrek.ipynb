# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#              Timestamp Kategori Anda Kategori Umur Anda  \
# 724  9/9/2019 15:30:46          Umum            > 40 th
# 725  9/9/2019 16:07:08         Dosen            < 25 th
# 726  9/9/2019 16:10:37         Dosen            < 25 th
# 727  9/9/2019 16:11:31        Alumni            < 25 th
# 728  9/9/2019 16:31:55        Alumni            > 40 th
#
#                        CaRek Pilihan  \
# 724       Edy Tri Baskoro (FMIPA-MA)
# 725   Ary Setiaji Prihatmanto (STEI)
# 726   Ary Setiaji Prihatmanto (STEI)
# 727   Ary Setiaji Prihatmanto (STEI)
# 728  Mikrajuddin Abdullah (FMIPA-FI)
#
#                                   Alasan Memilih CaRek           Harapan Anda
# 724  Kapabilitas ybs utk memajukan riset dan indust...  Semoga ITB lebih maju
# 725                          Keberhasilan dan prestasi                    NaN
# 726  Program ybs utk peningkatan income dan kesejah...                    NaN
# 727                          Keberhasilan dan prestasi                    NaN
# 728       Kapabilitas ybs utk meningkatkan ranking ITB                    NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            223
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
