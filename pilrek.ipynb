# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#              Timestamp Kategori Anda Kategori Umur Anda  \
# 421  9/3/2019 16:31:19          Umum         25 - 40 th
# 422  9/3/2019 16:43:12          Umum         25 - 40 th
# 423  9/3/2019 16:48:49     Mahasiswa            < 25 th
# 424  9/3/2019 16:48:58     Mahasiswa            < 25 th
# 425  9/3/2019 16:49:48     Mahasiswa            < 25 th
#
#                      CaRek Pilihan  \
# 421         Acep Purqon (FMIPA-FI)
# 422     Edy Tri Baskoro (FMIPA-MA)
# 423  Suhono Harso Supangkat (STEI)
# 424  Suhono Harso Supangkat (STEI)
# 425        Tutuka Ariaji (FTTM-TM)
#
#                                   Alasan Memilih CaRek  \
# 421               Karakter kepemimpinan dan leadership
# 422       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 423  Tipe yg futuristik dan outside-the-box yg bisa...
# 424       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 425  Keberhasilan & prestasi, cerdas & berani, memi...
#
#                                           Harapan Anda
# 421                                                NaN
# 422                                                NaN
# 423                   Semoga ITB mewujudkan E learning
# 424  Rektor memiliki visi untuk menjadikan ITB kamp...
# 425                                                NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            135
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
