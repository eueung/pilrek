# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#              Timestamp Kategori Anda Kategori Umur Anda  \
# 588  9/4/2019 17:38:22        Alumni            > 40 th
# 589  9/4/2019 17:38:24     Mahasiswa            > 40 th
# 590  9/4/2019 17:45:32         Dosen            > 40 th
# 591  9/4/2019 17:46:39     Mahasiswa            < 25 th
# 592  9/4/2019 18:07:17         Dosen         25 - 40 th
#
#                   CaRek Pilihan  \
# 588  Edy Tri Baskoro (FMIPA-MA)
# 589  Edy Tri Baskoro (FMIPA-MA)
# 590  Edy Tri Baskoro (FMIPA-MA)
# 591  Edy Tri Baskoro (FMIPA-MA)
# 592  Edy Tri Baskoro (FMIPA-MA)
#
#                                   Alasan Memilih CaRek  \
# 588  Kapabilitas ybs utk memajukan riset dan indust...
# 589                          Keberhasilan dan prestasi
# 590  Tipe yg futuristik dan outside-the-box yg bisa...
# 591                          Keberhasilan dan prestasi
# 592               Karakter kepemimpinan dan leadership
#
#                                           Harapan Anda
# 588  ITB semakin maju dan semakin bisa menggandeng ...
# 589                                Yang penting amanah
# 590  Meningkatkan peran ITB dalam penentuan arah ke...
# 591                                                NaN
# 592  ITB tetap mempertahankan kualitasnya dan menja...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            181
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
