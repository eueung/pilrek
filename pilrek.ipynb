# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#              Timestamp     Kategori Anda Kategori Umur Anda  \
# 546  9/4/2019 12:03:18             Dosen            > 40 th
# 547  9/4/2019 12:07:42  Pegawai / Tendik            < 25 th
# 548  9/4/2019 12:17:32              Umum            > 40 th
# 549  9/4/2019 12:47:38              Umum            > 40 th
# 550  9/4/2019 12:54:54              Umum            > 40 th
#
#                   CaRek Pilihan  \
# 546      Acep Purqon (FMIPA-FI)
# 547  Edy Tri Baskoro (FMIPA-MA)
# 548      Acep Purqon (FMIPA-FI)
# 549  Edy Tri Baskoro (FMIPA-MA)
# 550  Edy Tri Baskoro (FMIPA-MA)
#
#                                   Alasan Memilih CaRek  \
# 546       Sesuai dengan kriteria kekinian (Rektor 4.0)
# 547  Kapabilitas ybs utk memajukan riset dan indust...
# 548                          Keberhasilan dan prestasi
# 549               Karakter kepemimpinan dan leadership
# 550         Kecerdasan dan keberanian utk kemajuan ITB
#
#                                           Harapan Anda
# 546                                                NaN
# 547                                                NaN
# 548                     dipimpin beliau lebih visioner
# 549                                                NaN
# 550  Sukses membawa ITB lebih besar dan maju ..univ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            172
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
