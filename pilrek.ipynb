# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#             Timestamp Kategori Anda Kategori Umur Anda  \
# 356  9/3/2019 1:12:09        Alumni            > 40 th
# 357  9/3/2019 1:13:03        Alumni            > 40 th
# 358  9/3/2019 1:55:04        Alumni            > 40 th
# 359  9/3/2019 1:57:21        Alumni            > 40 th
# 360  9/3/2019 1:59:56        Alumni         25 - 40 th
#
#                   CaRek Pilihan  \
# 356  Edy Tri Baskoro (FMIPA-MA)
# 357  Edy Tri Baskoro (FMIPA-MA)
# 358  Edy Tri Baskoro (FMIPA-MA)
# 359   Kadarsah Suryadi (FTI-TI)
# 360      Acep Purqon (FMIPA-FI)
#
#                                   Alasan Memilih CaRek  \
# 356               Karakter kepemimpinan dan leadership
# 357                                   Dukung alumni MA
# 358  Kapabilitas ybs utk memajukan riset dan indust...
# 359                        rendah hati dan komunikatif
# 360       Sesuai dengan kriteria kekinian (Rektor 4.0)
#
#                                           Harapan Anda
# 356              ITB mandiri, berkarakter dan mendunia
# 357  Semoga rektor yad, dapat membawa ITB lebih ber...
# 358                                                NaN
# 359                                                NaN
# 360                 Mendatangkan kebaharuan di era 4.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            118
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
