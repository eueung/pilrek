# %%
import pandas as pd

# %%
url = 'https://github.com/eueung/pilrek/raw/master/pilrek.csv'
df  = pd.read_csv(url)

# %%
df.tail()
# Out:
#              Timestamp     Kategori Anda Kategori Umur Anda  \
# 386  9/3/2019 11:46:35            Alumni            < 25 th
# 387  9/3/2019 11:49:19              Umum         25 - 40 th
# 388  9/3/2019 12:23:28            Alumni            > 40 th
# 389  9/3/2019 12:30:18  Pegawai / Tendik         25 - 40 th
# 390  9/3/2019 12:39:03              Umum            > 40 th
#
#                        CaRek Pilihan  \
# 386  Mikrajuddin Abdullah (FMIPA-FI)
# 387          Khairurrijal (FMIPA-FI)
# 388           Acep Purqon (FMIPA-FI)
# 389    Suhono Harso Supangkat (STEI)
# 390           Acep Purqon (FMIPA-FI)
#
#                                   Alasan Memilih CaRek  \
# 386                          Keberhasilan dan prestasi
# 387                          Keberhasilan dan prestasi
# 388  Kapabilitas ybs utk memajukan riset dan indust...
# 389                          Keberhasilan dan prestasi
# 390  Mendatangkan dana riset dan kerjasama eksterna...
#
#                                   Harapan Anda
# 386                                        NaN
# 387  Semakin baik dg dipimpin bp. Khairrurijal
# 388                            Bisa kolaborasi
# 389                                        NaN
# 390                                        NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.shape
df.dtypes
# Out:
# Timestamp               object
# Kategori Anda           object
# Kategori Umur Anda      object
# CaRek Pilihan           object
# Alasan Memilih CaRek    object
# Harapan Anda            object
# dtype: object

# %%
df.isna().sum()
# Out:
# Timestamp                 0
# Kategori Anda             0
# Kategori Umur Anda        0
# CaRek Pilihan             0
# Alasan Memilih CaRek      0
# Harapan Anda            125
# dtype: int64

# %%
df['CaRek Pilihan'].value_counts().plot(kind='bar')

# %%
ax = df['Kategori Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Kategori Umur Anda'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
ax = df['Alasan Memilih CaRek'].value_counts().plot(kind='pie',autopct='%1.1f%%')
ax.set_ylabel('')
# Out:
# Text(0, 0.5, '')
